# %% [markdown]
# ## Loading the Database

# %%
import sys
import os

import mysql.connector
from mysql.connector import Error
import json
from datetime import datetime, timedelta

# Add the project root to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
if project_root not in sys.path:
    sys.path.append(project_root)
    
from app.database import create_connection  # Replace `function_name` with the specific function you want to import

connection = create_connection()

# %% [markdown]
# ## Insert Buildings, rooms, and avaiability

# %%
def load_buildings(connection, buildings):
    """
    Inserts building data into the buildings table.
    :param connection: MySQL connection
    :param buildings: Dictionary of building codes and names
    """
    cursor = connection.cursor()
    try:
        for code, name in buildings.items():
            cursor.execute("""
                INSERT IGNORE INTO buildings (building_code, building_name)
                VALUES (%s, %s);
            """, (code, name))
        connection.commit()
        print("Buildings loaded successfully!")
    except mysql.connector.Error as e:
        print(f"Error loading buildings: {e}")
    finally:
        cursor.close()



# Load buildings
buildings = {
    "ACE": "Accolade Building East",
    "ACW": "Accolade Building West",
    "AO": "Archives of Ontario",
    "ATK": "Atkinson",
    "BC": "Norman Bethune College",
    "BCSS": "Bennett Centre for Student Services",
    "BRG": "Bergeron Centre for Engineering Excellence",
    "BSB": "Behavioural Sciences Building",
    "BU": "Burton Auditorium",
    "CB": "Chemistry Building",
    "CC": "Calumet College",
    "CFA": "The Joan & Martin Goldfarb Centre for Fine Arts",
    "CFT": "Centre for Film and Theatre",
    "CLH": "Curtis Lecture Halls",
    "CMB": "Computer Methods Building",
    "CSQ": "Central Square",
    "CUB": "Central Utilities Building",
    "DB": "Dahdaleh Building (formerly TEL)",
    "ELC": "Executive Learning Centre",
    "FC": "Founders College",
    "FL": "Frost Library (Glendon campus)",
    "FRQ": "Farquharson Life Sciences",
    "FTC": "Founders Tennis Court",
    "GH": "Glendon Hall (Glendon campus)",
    "HC": "Lorna R. Marsden Honours Court & Welcome Centre",
    "HH": "Hart House (Osgoode Hall Law School)",
    "HNE": "Health, Nursing and Environmental Studies Building",
    "HR": "Hilliard Residence (Glendon campus)",
    "IKB": "Ignat Kaneff Building (Osgoode Hall Law School)",
    "K": "Kinsmen Building",
    "KT": "Kaneff Tower",
    "LAS": "Lassonde Building",
    "LMP": "LA&PS @ IBM Markham",
    "LSB": "Life Sciences Building",
    "LUM": "Lumbers Building",
    "MB": "Rob and Cheryl McEwen Graduate Study & Research Building",
    "MC": "McLaughlin College",
    "OC": "Off Campus (contact the department that offers the course)",
    "PR": "Physical Resources Building",
    "PSE": "Petrie Science and Engineering Building / Petrie Observatory",
    "R N": "Ross Building - North wing",
    "R S": "Ross Building - South wing",
    "SAY": "Seneca @ York",
    "SC": "Stong College",
    "SCL": "Scott Library",
    "SHR": "Sherman Health Science Research Centre",
    "SLH": "Stedman Lecture Halls",
    "SSB": "Seymour Schulich Building",
    "ST": "Sheridan College - Trafalgar Campus",
    "STC": "Student Centre",
    "STL": "Steacie Science and Engineering Library",
    "TC Sobeys": "Tennis Canada (TC Sobeys)",
    "TEL": "Technology and Enhanced Learning Building (effective summer 2016, Dahdaleh Building, DB)",
    "TFC": "Track and Field Centre",
    "TM Tait": "Tait McKenzie Centre (East/West)",
    "TTC": "Tait Tennis Courts",
    "VC": "Vanier College",
    "VH": "Vari Hall",
    "WC": "Winters College",
    "WOB": "West Office Building",
    "WSC": "William Small Centre",
    "YH": "York Hall (Glendon campus)",
    "YL": "York Lanes",
    "YSF FLDHSE": "York Student Fieldhouse (East/West) (Tait McKenzie Building)",
    "YSF FLDHSEE": "York Student Fieldhouse (East side only) (Tait McKenzie Building)",
    "YSF FLDHSEW": "York Student Fieldhouse (West side only) (Tait McKenzie Building)",
}
load_buildings(connection, buildings)
print("success")
# Out:
# Buildings loaded successfully!
# success

# %%
from datetime import datetime, timedelta

def load_rooms_and_availabilities(connection, data):
    """
    Inserts rooms into the database and calculates unoccupied time slots (availability).
    Handles full-day availability if a room is unoccupied for a given day.
    Includes all days from Monday to Sunday.
    :param connection: Active MySQL connection.
    :param data: Dictionary of room_name -> schedules.
    """
    try:
        # ✅ Use buffered cursor to avoid "Unread result" error
        cursor = connection.cursor(buffered=True)

        # Operating hours: 8:30 AM to 10:00 PM
        opening_time = datetime.strptime("08:30", "%H:%M")
        closing_time = datetime.strptime("22:00", "%H:%M")

        valid_days = {"M", "T", "W", "R", "F", "S", "U"}  # Include all days of the week

        for room_name, schedules in data.items():
            # Split the room name to get building code and room number
            parts = room_name.split(" ", 1)
            if len(parts) < 2:
                print(f"Invalid room name format: {room_name}. Skipping.")
                continue
            building_code, room_number = parts[0], parts[1]

            # Find building_id using building_code
            cursor.execute("SELECT building_id FROM buildings WHERE building_code = %s", (building_code,))
            result = cursor.fetchone()
            if not result:
                print(f"Building not found for code {building_code}. Skipping.")
                continue

            building_id = result[0]

            # Insert room into database
            cursor.execute("""
                INSERT INTO rooms (building_id, room_name)
                VALUES (%s, %s);
            """, (building_id, room_name))
            room_id = cursor.lastrowid
            print(f"Inserted room: {room_name}, ID: {room_id}")

            # Group occupied time slots by day
            occupied_slots = {day: [] for day in valid_days}
            for schedule in schedules:
                day = schedule.get("day")
                if day not in valid_days:
                    print(f"Invalid day code: {day}. Skipping.")
                    continue

                start_time = datetime.strptime(schedule["time"], "%H:%M")
                duration_minutes = int(schedule["duration"])
                end_time = start_time + timedelta(minutes=duration_minutes)
                occupied_slots[day].append((start_time, end_time))

            # Calculate unoccupied time slots for each day
            for day in valid_days:
                slots = occupied_slots[day]
                if not slots:
                    # Room is completely free for the entire day
                    cursor.execute("""
                        INSERT INTO availabilities (room_id, start_time, end_time, day)
                        VALUES (%s, %s, %s, %s);
                    """, (
                        room_id,
                        opening_time.strftime("%H:%M:%S"),
                        closing_time.strftime("%H:%M:%S"),
                        day
                    ))
                    print(f"Inserted full-day free slot: Room {room_name}, Day: {day}, Start: {opening_time}, End: {closing_time}")
                else:
                    # Sort occupied slots by start time
                    slots.sort(key=lambda x: x[0])
                    current_time = opening_time

                    for start, end in slots:
                        if current_time < start:
                            # Add unoccupied time before the next occupied slot
                            cursor.execute("""
                                INSERT INTO availabilities (room_id, start_time, end_time, day)
                                VALUES (%s, %s, %s, %s);
                            """, (
                                room_id,
                                current_time.strftime("%H:%M:%S"),
                                start.strftime("%H:%M:%S"),
                                day
                            ))
                            print(f"Inserted free slot: Room {room_name}, Day: {day}, Start: {current_time}, End: {start}")
                        current_time = max(current_time, end)

                    # Add remaining unoccupied time after the last occupied slot
                    if current_time < closing_time:
                        cursor.execute("""
                            INSERT INTO availabilities (room_id, start_time, end_time, day)
                            VALUES (%s, %s, %s, %s);
                        """, (
                            room_id,
                            current_time.strftime("%H:%M:%S"),
                            closing_time.strftime("%H:%M:%S"),
                            day
                        ))
                        print(f"Inserted free slot: Room {room_name}, Day: {day}, Start: {current_time}, End: {closing_time}")

        connection.commit()
        print("Rooms and availabilities loaded successfully.")
    except Exception as e:
        print(f"Error loading rooms and availabilities: {e}")
    finally:
        cursor.close()

# %%
def clear_all_availabilities(connection):
    """
    Deletes all entries from the availabilities table.
    """
    try:
        cursor = connection.cursor()
        cursor.execute("DELETE FROM availabilities;")
        cursor.execute("DELETE FROM rooms;")
        connection.commit()
        print("All availability data cleared.")
    except Exception as e:
        print(f"Error clearing availabilities: {e}")
    finally:
        cursor.close()

# %%
# Load new room schedules from JSON
import json
connection = create_connection()

with open("D:\Github\GIT\StudySpots\StudySpot\server\app\tools\scraped backup\Winter2026\emptyrooms_Winter2026\all_rooms_2026_01_02.json", "r") as f:
    room_data = json.load(f)

# Update availability only
clear_all_availabilities(connection)
# Out:
# All availability data cleared.

# %%
# Establish connection
connection = create_connection()

# Load rooms and availabilities from JSON
import json
with open("D:\Github\GIT\StudySpots\StudySpot\server\app\tools\scraped backup\Winter2026\emptyrooms_Winter2026\all_rooms_2026_01_02.json", "r") as f:
    room_data = json.load(f)

load_rooms_and_availabilities(connection, room_data)
# Out:
# Inserted room: WC 117, ID: 3851
# Inserted free slot: Room WC 117, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room WC 117, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room WC 117, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room WC 117, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room WC 117, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room WC 117, Day: M, Start: 1900-01-01 20:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room WC 117, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room WC 117, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room WC 117, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room WC 117, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room WC 117, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 16:30:00
# Inserted free slot: Room WC 117, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: SSB N109, ID: 3852
# Inserted free slot: Room SSB N109, Day: F, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N109, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N109, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N109, Day: T, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N109, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SSB N109, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room SSB N109, Day: T, Start: 1900-01-01 18:50:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N109, Day: T, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N109, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N109, Day: M, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N109, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N109, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N109, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N109, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N109, Day: R, Start: 1900-01-01 09:20:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N109, Day: R, Start: 1900-01-01 10:50:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N109, Day: R, Start: 1900-01-01 12:20:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N109, Day: R, Start: 1900-01-01 13:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N109, Day: W, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N109, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N109, Day: W, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N109, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N109, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N109, Day: W, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W141, ID: 3853
# Inserted free slot: Room SSB W141, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB W141, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W141, Day: F, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB W141, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W141, Day: F, Start: 1900-01-01 15:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W141, Day: T, Start: 1900-01-01 10:20:00, End: 1900-01-01 11:00:00
# Inserted free slot: Room SSB W141, Day: T, Start: 1900-01-01 13:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room SSB W141, Day: T, Start: 1900-01-01 15:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W141, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W141, Day: M, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB W141, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W141, Day: M, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB W141, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W141, Day: M, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SSB W141, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W141, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W141, Day: R, Start: 1900-01-01 10:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W141, Day: R, Start: 1900-01-01 13:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W141, Day: R, Start: 1900-01-01 16:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W141, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W141, Day: W, Start: 1900-01-01 13:50:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W141, Day: W, Start: 1900-01-01 16:20:00, End: 1900-01-01 22:00:00
# Inserted room: SSB N106, ID: 3854
# Inserted free slot: Room SSB N106, Day: F, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N106, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N106, Day: F, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N106, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N106, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N106, Day: T, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N106, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N106, Day: T, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SSB N106, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB N106, Day: T, Start: 1900-01-01 21:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N106, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N106, Day: M, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N106, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N106, Day: M, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N106, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N106, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N106, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N106, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N106, Day: R, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N106, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N106, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N106, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N106, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N106, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N106, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N106, Day: W, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W132, ID: 3855
# Inserted free slot: Room SSB W132, Day: F, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB W132, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W132, Day: F, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB W132, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W132, Day: T, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB W132, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W132, Day: T, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB W132, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W132, Day: T, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SSB W132, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W132, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W132, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W132, Day: M, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB W132, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W132, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB W132, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W132, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W132, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W132, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W132, Day: R, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SSB W132, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room SSB W132, Day: R, Start: 1900-01-01 18:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W132, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W132, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W132, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB W132, Day: W, Start: 1900-01-01 21:20:00, End: 1900-01-01 22:00:00
# Inserted room: SSB N105, ID: 3856
# Inserted full-day free slot: Room SSB N105, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N105, Day: T, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N105, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SSB N105, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room SSB N105, Day: T, Start: 1900-01-01 18:50:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N105, Day: T, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N105, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N105, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N105, Day: M, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N105, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N105, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N105, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N105, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N105, Day: R, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N105, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N105, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N105, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N105, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N105, Day: W, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N105, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N105, Day: W, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted room: SSB N107, ID: 3857
# Inserted free slot: Room SSB N107, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N107, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N107, Day: T, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N107, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N107, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N107, Day: T, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SSB N107, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room SSB N107, Day: T, Start: 1900-01-01 18:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N107, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N107, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N107, Day: M, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N107, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N107, Day: M, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SSB N107, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N107, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N107, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N107, Day: R, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N107, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N107, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N107, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB N107, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N107, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N107, Day: W, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N107, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N107, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB N107, Day: W, Start: 1900-01-01 21:20:00, End: 1900-01-01 22:00:00
# Inserted room: SSB E111, ID: 3858
# Inserted full-day free slot: Room SSB E111, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E111, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E111, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E111, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB E111, Day: T, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E111, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E111, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E111, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E111, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E111, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E111, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E111, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 18:00:00
# Inserted free slot: Room SSB E111, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E111, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E111, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E111, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E111, Day: W, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted room: SSB N108, ID: 3859
# Inserted free slot: Room SSB N108, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N108, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N108, Day: T, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N108, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N108, Day: T, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N108, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N108, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 18:00:00
# Inserted free slot: Room SSB N108, Day: T, Start: 1900-01-01 20:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N108, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N108, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N108, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N108, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N108, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N108, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N108, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N108, Day: R, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N108, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N108, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N108, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N108, Day: W, Start: 1900-01-01 09:50:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N108, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N108, Day: W, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N108, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N108, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 18:00:00
# Inserted free slot: Room SSB N108, Day: W, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted room: SSB E112, ID: 3860
# Inserted free slot: Room SSB E112, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E112, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E112, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E112, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E112, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E112, Day: T, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E112, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E112, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E112, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E112, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E112, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E112, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E112, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E112, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E112, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E112, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E112, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E112, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: SSB E118, ID: 3861
# Inserted free slot: Room SSB E118, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E118, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E118, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E118, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E118, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E118, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E118, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E118, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E118, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room SSB E118, Day: M, Start: 1900-01-01 20:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E118, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E118, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E118, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E118, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E118, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E118, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E118, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E118, Day: W, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W257, ID: 3862
# Inserted free slot: Room SSB W257, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB W257, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W257, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W257, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W257, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W257, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W257, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W257, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W257, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W257, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W257, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W257, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W257, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W257, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W257, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Invalid room name format: . Skipping.
# Inserted room: SSB E115, ID: 3863
# Inserted full-day free slot: Room SSB E115, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E115, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E115, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E115, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E115, Day: T, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E115, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E115, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E115, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E115, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E115, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E115, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E115, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E115, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E115, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB E115, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E115, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB E115, Day: W, Start: 1900-01-01 21:20:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W133, ID: 3864
# Inserted free slot: Room SSB W133, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room SSB W133, Day: F, Start: 1900-01-01 12:00:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W133, Day: F, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W133, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W133, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W133, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB W133, Day: T, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W133, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W133, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W133, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W133, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB W133, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W133, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W133, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W133, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W133, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W133, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W133, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W133, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: SSB S124, ID: 3865
# Inserted free slot: Room SSB S124, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S124, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S124, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S124, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB S124, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB S124, Day: T, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S124, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S124, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S124, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB S124, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB S124, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S124, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S124, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S124, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB S124, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB S124, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S124, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S124, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB S124, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W136, ID: 3866
# Inserted free slot: Room SSB W136, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W136, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W136, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W136, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB W136, Day: T, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W136, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W136, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W136, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W136, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W136, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W136, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W136, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W136, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB W136, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W136, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W136, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W136, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB W136, Day: W, Start: 1900-01-01 21:20:00, End: 1900-01-01 22:00:00
# Inserted room: SSB S126, ID: 3867
# Inserted free slot: Room SSB S126, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S126, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S126, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB S126, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S126, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S126, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S126, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB S126, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S126, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S126, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S126, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB S126, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB S126, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S126, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S126, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB S126, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: MB G102, ID: 3868
# Inserted free slot: Room MB G102, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G102, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room MB G102, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MB G102, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G102, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room MB G102, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room MB G102, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MB G102, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MB G102, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G102, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room MB G102, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room MB G102, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room MB G102, Day: W, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted room: MB G105, ID: 3869
# Inserted full-day free slot: Room MB G105, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G105, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room MB G105, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room MB G105, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MB G105, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G105, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room MB G105, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room MB G105, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room MB G105, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MB G105, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G105, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room MB G105, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room MB G105, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G105, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room MB G105, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room MB G105, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room MB G105, Day: W, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted room: SSB S125, ID: 3870
# Inserted free slot: Room SSB S125, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S125, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S125, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S125, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S125, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S125, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S125, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S125, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S125, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S125, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB S125, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: HNE 038, ID: 3871
# Inserted free slot: Room HNE 038, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room HNE 038, Day: F, Start: 1900-01-01 13:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room HNE 038, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room HNE 038, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room HNE 038, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room HNE 038, Day: T, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room HNE 038, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room HNE 038, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room HNE 038, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room HNE 038, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room HNE 038, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room HNE 038, Day: M, Start: 1900-01-01 18:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room HNE 038, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room HNE 038, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room HNE 038, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room HNE 038, Day: R, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room HNE 038, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room HNE 038, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room HNE 038, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room HNE 038, Day: W, Start: 1900-01-01 12:20:00, End: 1900-01-01 12:30:00
# Inserted free slot: Room HNE 038, Day: W, Start: 1900-01-01 13:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room HNE 038, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room HNE 038, Day: W, Start: 1900-01-01 16:20:00, End: 1900-01-01 22:00:00
# Inserted room: ACW 006, ID: 3872
# Inserted free slot: Room ACW 006, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ACW 006, Day: F, Start: 1900-01-01 12:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room ACW 006, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 15:30:00
# Inserted free slot: Room ACW 006, Day: F, Start: 1900-01-01 16:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 006, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room ACW 006, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 006, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room ACW 006, Day: T, Start: 1900-01-01 18:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 006, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 006, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ACW 006, Day: M, Start: 1900-01-01 10:50:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 006, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 15:30:00
# Inserted free slot: Room ACW 006, Day: M, Start: 1900-01-01 18:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 006, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 006, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room ACW 006, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 006, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACW 006, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 006, Day: W, Start: 1900-01-01 10:20:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room ACW 006, Day: W, Start: 1900-01-01 12:20:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room ACW 006, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 15:30:00
# Inserted free slot: Room ACW 006, Day: W, Start: 1900-01-01 18:50:00, End: 1900-01-01 22:00:00
# Inserted room: SLH A, ID: 3873
# Inserted free slot: Room SLH A, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room SLH A, Day: F, Start: 1900-01-01 12:20:00, End: 1900-01-01 12:30:00
# Inserted free slot: Room SLH A, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH A, Day: F, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH A, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH A, Day: T, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SLH A, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH A, Day: T, Start: 1900-01-01 16:20:00, End: 1900-01-01 16:30:00
# Inserted free slot: Room SLH A, Day: T, Start: 1900-01-01 18:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SLH A, Day: T, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH A, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH A, Day: M, Start: 1900-01-01 10:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH A, Day: M, Start: 1900-01-01 14:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SLH A, Day: M, Start: 1900-01-01 18:50:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SLH A, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH A, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH A, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH A, Day: R, Start: 1900-01-01 12:50:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SLH A, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH A, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SLH A, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH A, Day: W, Start: 1900-01-01 18:50:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SLH A, Day: W, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted room: SLH F, ID: 3874
# Inserted free slot: Room SLH F, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SLH F, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH F, Day: T, Start: 1900-01-01 10:20:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room SLH F, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH F, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH F, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH F, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH F, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH F, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH F, Day: M, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SLH F, Day: M, Start: 1900-01-01 18:50:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SLH F, Day: M, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH F, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH F, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room SLH F, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH F, Day: R, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH F, Day: R, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SLH F, Day: R, Start: 1900-01-01 18:50:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SLH F, Day: R, Start: 1900-01-01 21:50:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH F, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SLH F, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH F, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH F, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: CLH E, ID: 3875
# Inserted free slot: Room CLH E, Day: F, Start: 1900-01-01 09:20:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH E, Day: F, Start: 1900-01-01 10:20:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room CLH E, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CLH E, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH E, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room CLH E, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CLH E, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CLH E, Day: T, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room CLH E, Day: T, Start: 1900-01-01 18:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH E, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH E, Day: M, Start: 1900-01-01 09:20:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH E, Day: M, Start: 1900-01-01 10:20:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room CLH E, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CLH E, Day: M, Start: 1900-01-01 12:50:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CLH E, Day: M, Start: 1900-01-01 15:50:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room CLH E, Day: M, Start: 1900-01-01 18:50:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH E, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# ...
# Inserted free slot: Room ACE 207, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 207, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 207, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACE 207, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACE 207, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room ACE 207, Day: M, Start: 1900-01-01 20:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 207, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 207, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACE 207, Day: R, Start: 1900-01-01 13:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACE 207, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 207, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACE 207, Day: W, Start: 1900-01-01 13:20:00, End: 1900-01-01 22:00:00
# Inserted room: ACE 209, ID: 4315
# Inserted full-day free slot: Room ACE 209, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 209, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACE 209, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 209, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 209, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACE 209, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACE 209, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 209, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 209, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACE 209, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 209, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 139, ID: 4316
# Inserted free slot: Room CFT 139, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFT 139, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 139, Day: F, Start: 1900-01-01 13:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 139, Day: F, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 139, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFT 139, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 139, Day: T, Start: 1900-01-01 13:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 139, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 139, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 139, Day: M, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 139, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 139, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFT 139, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 139, Day: R, Start: 1900-01-01 13:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 139, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 139, Day: W, Start: 1900-01-01 13:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 139, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: ACE 132, ID: 4317
# Inserted full-day free slot: Room ACE 132, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 132, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACE 132, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 132, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 132, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 132, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 132, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 132, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACE 132, Day: W, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACE 132, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 142, ID: 4318
# Inserted free slot: Room CFT 142, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 142, Day: F, Start: 1900-01-01 13:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 142, Day: F, Start: 1900-01-01 16:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 142, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 142, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 142, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 142, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 142, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 142, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 142, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFT 142, Day: R, Start: 1900-01-01 13:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 142, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 142, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 142, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: ATK 102F, ID: 4319
# Inserted free slot: Room ATK 102F, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ATK 102F, Day: F, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ATK 102F, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ATK 102F, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ATK 102F, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ATK 102F, Day: T, Start: 1900-01-01 13:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ATK 102F, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ATK 102F, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ATK 102F, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ATK 102F, Day: M, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ATK 102F, Day: M, Start: 1900-01-01 13:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ATK 102F, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ATK 102F, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ATK 102F, Day: R, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ATK 102F, Day: R, Start: 1900-01-01 13:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ATK 102F, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ATK 102F, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ATK 102F, Day: W, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ATK 102F, Day: W, Start: 1900-01-01 13:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ATK 102F, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 105A, ID: 4320
# Inserted full-day free slot: Room CFT 105A, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 105A, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 105A, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 105A, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 105A, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 105A, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 105A, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 105A, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 105A, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 301, ID: 4321
# Inserted free slot: Room CFT 301, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 301, Day: F, Start: 1900-01-01 14:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 301, Day: T, Start: 1900-01-01 11:20:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 301, Day: T, Start: 1900-01-01 14:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 301, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 301, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 301, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 301, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 301, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 301, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 301, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 154, ID: 4322
# Inserted full-day free slot: Room CFT 154, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 154, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 154, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 154, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 154, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 154, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 154, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 154, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 155, ID: 4323
# Inserted full-day free slot: Room CFT 155, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 155, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 155, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFA 282, ID: 4324
# Inserted free slot: Room CFA 282, Day: F, Start: 1900-01-01 13:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 282, Day: F, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 282, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 282, Day: T, Start: 1900-01-01 13:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 282, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 282, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 282, Day: M, Start: 1900-01-01 12:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 282, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 282, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 282, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 282, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 282, Day: W, Start: 1900-01-01 12:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFA 282, Day: W, Start: 1900-01-01 18:20:00, End: 1900-01-01 22:00:00
# Inserted room: CFA 284, ID: 4325
# Inserted free slot: Room CFA 284, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 284, Day: F, Start: 1900-01-01 13:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 284, Day: F, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 284, Day: T, Start: 1900-01-01 13:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 284, Day: T, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 284, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 284, Day: M, Start: 1900-01-01 12:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 284, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room CFA 284, Day: M, Start: 1900-01-01 21:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 284, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 284, Day: R, Start: 1900-01-01 12:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 284, Day: R, Start: 1900-01-01 17:20:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room CFA 284, Day: R, Start: 1900-01-01 21:20:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 284, Day: W, Start: 1900-01-01 12:20:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFA 284, Day: W, Start: 1900-01-01 20:20:00, End: 1900-01-01 22:00:00
# Inserted room: CFA 106, ID: 4326
# Inserted free slot: Room CFA 106, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 106, Day: F, Start: 1900-01-01 13:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 106, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 106, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 106, Day: M, Start: 1900-01-01 12:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 106, Day: M, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 106, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 106, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 106, Day: W, Start: 1900-01-01 12:20:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 106, Day: W, Start: 1900-01-01 17:20:00, End: 1900-01-01 22:00:00
# Rooms and availabilities loaded successfully.

# %% [markdown]
# # Updating the availability everymonth.

# %% [markdown]
# # Testing Cafes and Libraries

# %%
import sys
import os

import mysql.connector
from mysql.connector import Error
import json
from datetime import datetime, timedelta

# Add the project root to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

from app.database import get_cafes, get_libraries, get_lecture_halls

cafes = get_cafes()

print(cafes)

libraries = get_libraries()

print(libraries)

lecture_halls = get_lecture_halls()

print(lecture_halls)
# Out:
# Starting get_cafes function...
# Database connection closed.
# [{'building': 'Aroma Espresso Bar - Pond', 'location': (-79.50186839999999, 43.7734535), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:30', 'EndTime': '22:00', 'Status': []}]}, {'building': 'Aroma Espresso Bar - York Lanes', 'location': (-79.5018478, 43.7742143), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:30', 'EndTime': '21:00', 'Status': []}]}, {'building': 'Break Cafe - Second Student Center', 'location': (-79.503864, 43.7715346), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '20:00', 'Status': []}]}, {'building': 'La Prep - York Lanes', 'location': (-79.5018478, 43.7742143), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '21:00', 'Status': []}]}, {'building': 'Schulich Market Cafe - Schulich School of Business', 'location': (-79.498257, 43.773227), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:00', 'EndTime': '21:00', 'Status': []}]}, {'building': 'Starbucks - ACW', 'location': (-79.3831843, 43.653226), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:30', 'EndTime': '21:00', 'Status': []}]}, {'building': 'Starbucks - Central Square', 'location': (-79.50489999999999, 43.7728891), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '19:00', 'Status': []}]}, {'building': 'The Great Canadian Bagel - York Lanes', 'location': (-79.5018478, 43.7742143), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '19:00', 'Status': []}]}, {'building': 'Tim Hortons - Central Square', 'location': (-79.50436359999999, 43.7721373), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:30', 'EndTime': '20:00', 'Status': []}]}, {'building': 'Tim Hortons - William Small Center', 'location': (-79.50777769999999, 43.77294500000001), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:00', 'EndTime': '18:00', 'Status': []}]}]
# Starting get_libraries function...
# Database connection closed.
# [{'building': 'Bronfman Library', 'location': (-79.4987993, 43.7734232), 'building_code': '', 'website': 'https://yorku.libcal.com/r/new/availability?lid=2607&zone=737&gid=0&capacity=-1', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '09:00', 'EndTime': '21:00', 'Status': ''}]}, {'building': 'Scott Library', 'location': (-79.5055508, 43.7723418), 'building_code': '', 'website': 'https://yorku.libcal.com/r/new/availability?lid=2218&zone=0&gid=0&capacity=-1', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '23:00', 'Status': ''}]}, {'building': 'Steacie Library', 'location': (-79.505845, 43.773608), 'building_code': '', 'website': 'https://yorku.libcal.com/r/new/availability?lid=2286&zone=0&gid=4527&capacity=-1', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '09:00', 'EndTime': '21:00', 'Status': ''}]}]
# Starting get_lecture_halls function...
# The current time in Toronto is 2025-09-03 22:25:56 and the day is W.
# Lec Halls, Database connection closed.
# [{'building': 'Accolade Building East', 'building_code': 'ACE', 'location': (-79.4993904, 43.7725551), 'building_status': '', 'rooms': {'ACE 001': {'roomNumber': 'ACE 001', 'slots': [{'StartTime': '11:20', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '17:20', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 002': {'roomNumber': 'ACE 002', 'slots': [{'StartTime': '09:20', 'EndTime': '09:30', 'Status': ''}, {'StartTime': '11:20', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '17:20', 'EndTime': '19:00', 'Status': ''}, {'StartTime': '21:50', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 003': {'roomNumber': 'ACE 003', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '15:30', 'Status': ''}, {'StartTime': '16:20', 'EndTime': '16:30', 'Status': ''}, {'StartTime': '19:20', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 004': {'roomNumber': 'ACE 004', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 005': {'roomNumber': 'ACE 005', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '18:50', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 006': {'roomNumber': 'ACE 006', 'slots': [{'StartTime': '08:30', 'EndTime': '10:30', 'Status': ''}, {'StartTime': '12:20', 'EndTime': '12:30', 'Status': ''}, {'StartTime': '13:20', 'EndTime': '13:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '15:20', 'EndTime': '15:30', 'Status': ''}, {'StartTime': '16:20', 'EndTime': '16:30', 'Status': ''}, {'StartTime': '17:20', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 007': {'roomNumber': 'ACE 007', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '12:20', 'EndTime': '12:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '18:50', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 008': {'roomNumber': 'ACE 008', 'slots': [{'StartTime': '11:20', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '17:20', 'EndTime': '19:00', 'Status': ''}, {'StartTime': '21:50', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 009': {'roomNumber': 'ACE 009', 'slots': [{'StartTime': '11:20', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '13:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '17:20', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 010': {'roomNumber': 'ACE 010', 'slots': [{'StartTime': '08:30', 'EndTime': '10:00', 'Status': ''}, {'StartTime': '11:20', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '15:20', 'EndTime': '15:30', 'Status': ''}, {'StartTime': '16:20', 'EndTime': '16:30', 'Status': ''}, {'StartTime': '17:20', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 011': {'roomNumber': 'ACE 011', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '18:50', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 012': {'roomNumber': 'ACE 012', 'slots': [{'StartTime': '08:30', 'EndTime': '09:30', 'Status': ''}, {'StartTime': '10:20', 'EndTime': '10:30', 'Status': ''}, {'StartTime': '12:20', 'EndTime': '12:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '17:20', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 013': {'roomNumber': 'ACE 013', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '18:50', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 021': {'roomNumber': 'ACE 021', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:20', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '17:20', 'EndTime': '22:00', 'Stat ...
