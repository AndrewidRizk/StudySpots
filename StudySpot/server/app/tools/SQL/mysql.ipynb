# %% [markdown]
# ## Loading the Database

# %%
import sys
import os

import mysql.connector
from mysql.connector import Error
import json
from datetime import datetime, timedelta

# Add the project root to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
if project_root not in sys.path:
    sys.path.append(project_root)
    
from app.database import create_connection  # Replace `function_name` with the specific function you want to import

connection = create_connection()

# %% [markdown]
# ## Insert Buildings, rooms, and avaiability

# %%
def load_buildings(connection, buildings):
    """
    Inserts building data into the buildings table.
    :param connection: MySQL connection
    :param buildings: Dictionary of building codes and names
    """
    cursor = connection.cursor()
    try:
        for code, name in buildings.items():
            cursor.execute("""
                INSERT IGNORE INTO buildings (building_code, building_name)
                VALUES (%s, %s);
            """, (code, name))
        connection.commit()
        print("Buildings loaded successfully!")
    except mysql.connector.Error as e:
        print(f"Error loading buildings: {e}")
    finally:
        cursor.close()



# Load buildings
buildings = {
    "ACE": "Accolade Building East",
    "ACW": "Accolade Building West",
    "AO": "Archives of Ontario",
    "ATK": "Atkinson",
    "BC": "Norman Bethune College",
    "BCSS": "Bennett Centre for Student Services",
    "BRG": "Bergeron Centre for Engineering Excellence",
    "BSB": "Behavioural Sciences Building",
    "BU": "Burton Auditorium",
    "CB": "Chemistry Building",
    "CC": "Calumet College",
    "CFA": "The Joan & Martin Goldfarb Centre for Fine Arts",
    "CFT": "Centre for Film and Theatre",
    "CLH": "Curtis Lecture Halls",
    "CMB": "Computer Methods Building",
    "CSQ": "Central Square",
    "CUB": "Central Utilities Building",
    "DB": "Dahdaleh Building (formerly TEL)",
    "ELC": "Executive Learning Centre",
    "FC": "Founders College",
    "FL": "Frost Library (Glendon campus)",
    "FRQ": "Farquharson Life Sciences",
    "FTC": "Founders Tennis Court",
    "GH": "Glendon Hall (Glendon campus)",
    "HC": "Lorna R. Marsden Honours Court & Welcome Centre",
    "HH": "Hart House (Osgoode Hall Law School)",
    "HNE": "Health, Nursing and Environmental Studies Building",
    "HR": "Hilliard Residence (Glendon campus)",
    "IKB": "Ignat Kaneff Building (Osgoode Hall Law School)",
    "K": "Kinsmen Building",
    "KT": "Kaneff Tower",
    "LAS": "Lassonde Building",
    "LMP": "LA&PS @ IBM Markham",
    "LSB": "Life Sciences Building",
    "LUM": "Lumbers Building",
    "MB": "Rob and Cheryl McEwen Graduate Study & Research Building",
    "MC": "McLaughlin College",
    "OC": "Off Campus (contact the department that offers the course)",
    "PR": "Physical Resources Building",
    "PSE": "Petrie Science and Engineering Building / Petrie Observatory",
    "R N": "Ross Building - North wing",
    "R S": "Ross Building - South wing",
    "SAY": "Seneca @ York",
    "SC": "Stong College",
    "SCL": "Scott Library",
    "SHR": "Sherman Health Science Research Centre",
    "SLH": "Stedman Lecture Halls",
    "SSB": "Seymour Schulich Building",
    "ST": "Sheridan College - Trafalgar Campus",
    "STC": "Student Centre",
    "STL": "Steacie Science and Engineering Library",
    "TC Sobeys": "Tennis Canada (TC Sobeys)",
    "TEL": "Technology and Enhanced Learning Building (effective summer 2016, Dahdaleh Building, DB)",
    "TFC": "Track and Field Centre",
    "TM Tait": "Tait McKenzie Centre (East/West)",
    "TTC": "Tait Tennis Courts",
    "VC": "Vanier College",
    "VH": "Vari Hall",
    "WC": "Winters College",
    "WOB": "West Office Building",
    "WSC": "William Small Centre",
    "YH": "York Hall (Glendon campus)",
    "YL": "York Lanes",
    "YSF FLDHSE": "York Student Fieldhouse (East/West) (Tait McKenzie Building)",
    "YSF FLDHSEE": "York Student Fieldhouse (East side only) (Tait McKenzie Building)",
    "YSF FLDHSEW": "York Student Fieldhouse (West side only) (Tait McKenzie Building)",
}
load_buildings(connection, buildings)
print("success")
# Out:
# Buildings loaded successfully!
# success

# %%
from datetime import datetime, timedelta

def load_rooms_and_availabilities(connection, data):
    """
    Inserts rooms into the database and calculates unoccupied time slots (availability).
    Handles full-day availability if a room is unoccupied for a given day.
    Includes all days from Monday to Sunday.
    :param connection: Active MySQL connection.
    :param data: Dictionary of room_name -> schedules.
    """
    try:
        # ✅ Use buffered cursor to avoid "Unread result" error
        cursor = connection.cursor(buffered=True)

        # Operating hours: 8:30 AM to 10:00 PM
        opening_time = datetime.strptime("08:30", "%H:%M")
        closing_time = datetime.strptime("22:00", "%H:%M")

        valid_days = {"M", "T", "W", "R", "F", "S", "U"}  # Include all days of the week

        for room_name, schedules in data.items():
            # Split the room name to get building code and room number
            parts = room_name.split(" ", 1)
            if len(parts) < 2:
                print(f"Invalid room name format: {room_name}. Skipping.")
                continue
            building_code, room_number = parts[0], parts[1]

            # Find building_id using building_code
            cursor.execute("SELECT building_id FROM buildings WHERE building_code = %s", (building_code,))
            result = cursor.fetchone()
            if not result:
                print(f"Building not found for code {building_code}. Skipping.")
                continue

            building_id = result[0]

            # Insert room into database
            cursor.execute("""
                INSERT INTO rooms (building_id, room_name)
                VALUES (%s, %s);
            """, (building_id, room_name))
            room_id = cursor.lastrowid
            print(f"Inserted room: {room_name}, ID: {room_id}")

            # Group occupied time slots by day
            occupied_slots = {day: [] for day in valid_days}
            for schedule in schedules:
                day = schedule.get("day")
                if day not in valid_days:
                    print(f"Invalid day code: {day}. Skipping.")
                    continue

                start_time = datetime.strptime(schedule["time"], "%H:%M")
                duration_minutes = int(schedule["duration"])
                end_time = start_time + timedelta(minutes=duration_minutes)
                occupied_slots[day].append((start_time, end_time))

            # Calculate unoccupied time slots for each day
            for day in valid_days:
                slots = occupied_slots[day]
                if not slots:
                    # Room is completely free for the entire day
                    cursor.execute("""
                        INSERT INTO availabilities (room_id, start_time, end_time, day)
                        VALUES (%s, %s, %s, %s);
                    """, (
                        room_id,
                        opening_time.strftime("%H:%M:%S"),
                        closing_time.strftime("%H:%M:%S"),
                        day
                    ))
                    print(f"Inserted full-day free slot: Room {room_name}, Day: {day}, Start: {opening_time}, End: {closing_time}")
                else:
                    # Sort occupied slots by start time
                    slots.sort(key=lambda x: x[0])
                    current_time = opening_time

                    for start, end in slots:
                        if current_time < start:
                            # Add unoccupied time before the next occupied slot
                            cursor.execute("""
                                INSERT INTO availabilities (room_id, start_time, end_time, day)
                                VALUES (%s, %s, %s, %s);
                            """, (
                                room_id,
                                current_time.strftime("%H:%M:%S"),
                                start.strftime("%H:%M:%S"),
                                day
                            ))
                            print(f"Inserted free slot: Room {room_name}, Day: {day}, Start: {current_time}, End: {start}")
                        current_time = max(current_time, end)

                    # Add remaining unoccupied time after the last occupied slot
                    if current_time < closing_time:
                        cursor.execute("""
                            INSERT INTO availabilities (room_id, start_time, end_time, day)
                            VALUES (%s, %s, %s, %s);
                        """, (
                            room_id,
                            current_time.strftime("%H:%M:%S"),
                            closing_time.strftime("%H:%M:%S"),
                            day
                        ))
                        print(f"Inserted free slot: Room {room_name}, Day: {day}, Start: {current_time}, End: {closing_time}")

        connection.commit()
        print("Rooms and availabilities loaded successfully.")
    except Exception as e:
        print(f"Error loading rooms and availabilities: {e}")
    finally:
        cursor.close()

# %%
def clear_all_availabilities(connection):
    """
    Deletes all entries from the availabilities table.
    """
    try:
        cursor = connection.cursor()
        cursor.execute("DELETE FROM availabilities;")
        cursor.execute("DELETE FROM rooms;")
        connection.commit()
        print("All availability data cleared.")
    except Exception as e:
        print(f"Error clearing availabilities: {e}")
    finally:
        cursor.close()

# %%
# Load new room schedules from JSON
import json
connection = create_connection()

with open("../scraped backup/emptyrooms_Sum2025/all_rooms_Sum2025.json", "r") as f:
    room_data = json.load(f)

# Update availability only
clear_all_availabilities(connection)
# Out:
# All availability data cleared.

# %%
# Establish connection
connection = create_connection()

# Load rooms and availabilities from JSON
import json
with open("../scraped backup/emptyrooms_Sum2025/all_rooms_Sum2025.json", "r") as f:
    room_data = json.load(f)

load_rooms_and_availabilities(connection, room_data)
# Out:
# Inserted room: SSB E118, ID: 3489
# Inserted full-day free slot: Room SSB E118, Day: F
# Inserted full-day free slot: Room SSB E118, Day: T
# Inserted free slot: Room SSB E118, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room SSB E118, Day: R, Start: 17:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB E118, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room SSB E118, Day: M, Start: 08:30:00, End: 13:00:00
# Inserted free slot: Room SSB E118, Day: M, Start: 15:50:00, End: 18:00:00
# Inserted free slot: Room SSB E118, Day: M, Start: 19:50:00, End: 20:00:00
# Inserted end-of-day free slot: Room SSB E118, Day: M, Start: 21:20:00, End: 22:00:00
# Inserted full-day free slot: Room SSB E118, Day: S
# Inserted free slot: Room SSB E118, Day: W, Start: 08:30:00, End: 13:00:00
# Inserted free slot: Room SSB E118, Day: W, Start: 15:50:00, End: 18:00:00
# Inserted free slot: Room SSB E118, Day: W, Start: 19:50:00, End: 20:00:00
# Inserted end-of-day free slot: Room SSB E118, Day: W, Start: 21:20:00, End: 22:00:00
# Inserted full-day free slot: Room SSB E118, Day: U
# Inserted room: SSB E112, ID: 3490
# Inserted full-day free slot: Room SSB E112, Day: F
# Inserted free slot: Room SSB E112, Day: T, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB E112, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room SSB E112, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room SSB E112, Day: R, Start: 12:50:00, End: 18:30:00
# Inserted end-of-day free slot: Room SSB E112, Day: R, Start: 21:20:00, End: 22:00:00
# Inserted free slot: Room SSB E112, Day: M, Start: 11:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room SSB E112, Day: M, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room SSB E112, Day: S
# Inserted free slot: Room SSB E112, Day: W, Start: 11:20:00, End: 13:00:00
# Inserted free slot: Room SSB E112, Day: W, Start: 15:50:00, End: 17:00:00
# Inserted end-of-day free slot: Room SSB E112, Day: W, Start: 19:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB E112, Day: U
# Inserted room: SSB E115, ID: 3491
# Inserted full-day free slot: Room SSB E115, Day: F
# Inserted free slot: Room SSB E115, Day: T, Start: 08:30:00, End: 13:00:00
# Inserted free slot: Room SSB E115, Day: T, Start: 15:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB E115, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room SSB E115, Day: R, Start: 08:30:00, End: 13:00:00
# Inserted free slot: Room SSB E115, Day: R, Start: 15:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB E115, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room SSB E115, Day: M, Start: 08:30:00, End: 13:00:00
# Inserted free slot: Room SSB E115, Day: M, Start: 15:50:00, End: 18:30:00
# Inserted end-of-day free slot: Room SSB E115, Day: M, Start: 21:20:00, End: 22:00:00
# Inserted full-day free slot: Room SSB E115, Day: S
# Inserted free slot: Room SSB E115, Day: W, Start: 08:30:00, End: 13:00:00
# Inserted free slot: Room SSB E115, Day: W, Start: 15:50:00, End: 17:00:00
# Inserted end-of-day free slot: Room SSB E115, Day: W, Start: 19:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB E115, Day: U
# Inserted room: SSB N107, ID: 3492
# Inserted full-day free slot: Room SSB N107, Day: F
# Inserted full-day free slot: Room SSB N107, Day: T
# Inserted free slot: Room SSB N107, Day: R, Start: 08:30:00, End: 09:00:00
# Inserted free slot: Room SSB N107, Day: R, Start: 11:50:00, End: 13:00:00
# Inserted free slot: Room SSB N107, Day: R, Start: 15:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB N107, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room SSB N107, Day: M, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room SSB N107, Day: M, Start: 17:20:00, End: 18:30:00
# Inserted end-of-day free slot: Room SSB N107, Day: M, Start: 21:20:00, End: 22:00:00
# Inserted full-day free slot: Room SSB N107, Day: S
# Inserted free slot: Room SSB N107, Day: W, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room SSB N107, Day: W, Start: 12:50:00, End: 14:30:00
# Inserted free slot: Room SSB N107, Day: W, Start: 17:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB N107, Day: W, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB N107, Day: U
# Invalid room name format: . Skipping.
# Inserted room: SSB W133, ID: 3493
# Inserted full-day free slot: Room SSB W133, Day: F
# Inserted free slot: Room SSB W133, Day: T, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room SSB W133, Day: T, Start: 12:50:00, End: 14:30:00
# Inserted free slot: Room SSB W133, Day: T, Start: 17:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB W133, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room SSB W133, Day: R, Start: 11:20:00, End: 14:30:00
# Inserted free slot: Room SSB W133, Day: R, Start: 17:20:00, End: 17:30:00
# Inserted end-of-day free slot: Room SSB W133, Day: R, Start: 20:20:00, End: 22:00:00
# Inserted free slot: Room SSB W133, Day: M, Start: 08:30:00, End: 18:30:00
# Inserted end-of-day free slot: Room SSB W133, Day: M, Start: 21:20:00, End: 22:00:00
# Inserted full-day free slot: Room SSB W133, Day: S
# Inserted free slot: Room SSB W133, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room SSB W133, Day: W, Start: 14:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB W133, Day: W, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB W133, Day: U
# Inserted room: SSB N106, ID: 3494
# Inserted full-day free slot: Room SSB N106, Day: F
# Inserted end-of-day free slot: Room SSB N106, Day: T, Start: 11:20:00, End: 22:00:00
# Inserted free slot: Room SSB N106, Day: R, Start: 11:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room SSB N106, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room SSB N106, Day: M, Start: 08:30:00, End: 09:00:00
# Inserted free slot: Room SSB N106, Day: M, Start: 11:50:00, End: 13:00:00
# Inserted free slot: Room SSB N106, Day: M, Start: 15:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB N106, Day: M, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB N106, Day: S
# Inserted free slot: Room SSB N106, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room SSB N106, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room SSB N106, Day: U
# Inserted room: SSB E111, ID: 3495
# Inserted full-day free slot: Room SSB E111, Day: F
# Inserted free slot: Room SSB E111, Day: T, Start: 08:30:00, End: 09:00:00
# Inserted free slot: Room SSB E111, Day: T, Start: 11:50:00, End: 13:00:00
# Inserted end-of-day free slot: Room SSB E111, Day: T, Start: 15:50:00, End: 22:00:00
# Inserted free slot: Room SSB E111, Day: R, Start: 08:30:00, End: 13:00:00
# Inserted end-of-day free slot: Room SSB E111, Day: R, Start: 15:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB E111, Day: M
# Inserted full-day free slot: Room SSB E111, Day: S
# Inserted free slot: Room SSB E111, Day: W, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB E111, Day: W, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB E111, Day: U
# Inserted room: SSB N108, ID: 3496
# Inserted full-day free slot: Room SSB N108, Day: F
# Inserted free slot: Room SSB N108, Day: T, Start: 08:30:00, End: 18:30:00
# Inserted end-of-day free slot: Room SSB N108, Day: T, Start: 21:20:00, End: 22:00:00
# Inserted free slot: Room SSB N108, Day: R, Start: 08:30:00, End: 09:00:00
# Inserted free slot: Room SSB N108, Day: R, Start: 11:50:00, End: 13:00:00
# Inserted free slot: Room SSB N108, Day: R, Start: 15:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB N108, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room SSB N108, Day: M, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room SSB N108, Day: M, Start: 17:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB N108, Day: M, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB N108, Day: S
# Inserted free slot: Room SSB N108, Day: W, Start: 08:30:00, End: 09:00:00
# Inserted free slot: Room SSB N108, Day: W, Start: 11:50:00, End: 13:00:00
# Inserted end-of-day free slot: Room SSB N108, Day: W, Start: 15:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB N108, Day: U
# Inserted room: SSB N105, ID: 3497
# Inserted full-day free slot: Room SSB N105, Day: F
# Inserted free slot: Room SSB N105, Day: T, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB N105, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room SSB N105, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room SSB N105, Day: R, Start: 17:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB N105, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room SSB N105, Day: M, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room SSB N105, Day: M, Start: 17:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB N105, Day: M, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB N105, Day: S
# Inserted free slot: Room SSB N105, Day: W, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB N105, Day: W, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB N105, Day: U
# Inserted room: VH D, ID: 3498
# Inserted full-day free slot: Room VH D, Day: F
# Inserted free slot: Room VH D, Day: T, Start: 11:20:00, End: 16:00:00
# Inserted free slot: Room VH D, Day: T, Start: 18:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room VH D, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room VH D, Day: R, Start: 11:20:00, End: 11:30:00
# Inserted end-of-day free slot: Room VH D, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room VH D, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room VH D, Day: M, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room VH D, Day: M, Start: 16:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH D, Day: S
# Inserted free slot: Room VH D, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room VH D, Day: W, Start: 16:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room VH D, Day: W, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room VH D, Day: U
# Inserted room: ACW 005, ID: 3499
# Inserted full-day free slot: Room ACW 005, Day: F
# Inserted free slot: Room ACW 005, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room ACW 005, Day: T, Start: 14:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room ACW 005, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 005, Day: R
# Inserted full-day free slot: Room ACW 005, Day: M
# Inserted full-day free slot: Room ACW 005, Day: S
# Inserted full-day free slot: Room ACW 005, Day: W
# Inserted full-day free slot: Room ACW 005, Day: U
# Inserted room: CLH E, ID: 3500
# Inserted full-day free slot: Room CLH E, Day: F
# Inserted free slot: Room CLH E, Day: T, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room CLH E, Day: T, Start: 11:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room CLH E, Day: T, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room CLH E, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room CLH E, Day: R, Start: 11:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room CLH E, Day: R, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room CLH E, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room CLH E, Day: M, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room CLH E, Day: S
# Inserted free slot: Room CLH E, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room CLH E, Day: W, Start: 14:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room CLH E, Day: W, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room CLH E, Day: U
# Inserted room: DB 0014, ID: 3501
# Inserted full-day free slot: Room DB 0014, Day: F
# Inserted free slot: Room DB 0014, Day: T, Start: 08:30:00, End: 16:00:00
# Inserted end-of-day free slot: Room DB 0014, Day: T, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room DB 0014, Day: R, Start: 08:30:00, End: 16:00:00
# Inserted end-of-day free slot: Room DB 0014, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room DB 0014, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0014, Day: M, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room DB 0014, Day: M, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0014, Day: S
# Inserted free slot: Room DB 0014, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0014, Day: W, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room DB 0014, Day: W, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0014, Day: U
# Inserted room: CLH A, ID: 3502
# Inserted full-day free slot: Room CLH A, Day: F
# Inserted full-day free slot: Room CLH A, Day: T
# Inserted free slot: Room CLH A, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room CLH A, Day: R, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room CLH A, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room CLH A, Day: M
# Inserted full-day free slot: Room CLH A, Day: S
# Inserted free slot: Room CLH A, Day: W, Start: 08:30:00, End: 18:00:00
# Inserted end-of-day free slot: Room CLH A, Day: W, Start: 20:50:00, End: 22:00:00
# Inserted full-day free slot: Room CLH A, Day: U
# Inserted room: ACW 004, ID: 3503
# Inserted full-day free slot: Room ACW 004, Day: F
# Inserted free slot: Room ACW 004, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room ACW 004, Day: T, Start: 14:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room ACW 004, Day: T, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 004, Day: R
# Inserted free slot: Room ACW 004, Day: M, Start: 08:30:00, End: 10:30:00
# Inserted end-of-day free slot: Room ACW 004, Day: M, Start: 12:20:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 004, Day: S
# Inserted free slot: Room ACW 004, Day: W, Start: 08:30:00, End: 10:30:00
# Inserted end-of-day free slot: Room ACW 004, Day: W, Start: 12:20:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 004, Day: U
# Inserted room: DB 1004, ID: 3504
# Inserted full-day free slot: Room DB 1004, Day: F
# Inserted free slot: Room DB 1004, Day: T, Start: 08:30:00, End: 15:00:00
# Inserted free slot: Room DB 1004, Day: T, Start: 17:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 1004, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room DB 1004, Day: R, Start: 08:30:00, End: 11:00:00
# Inserted free slot: Room DB 1004, Day: R, Start: 13:50:00, End: 14:30:00
# Inserted free slot: Room DB 1004, Day: R, Start: 17:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 1004, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room DB 1004, Day: M, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room DB 1004, Day: M, Start: 17:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 1004, Day: M, Start: 20:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 1004, Day: S
# Inserted free slot: Room DB 1004, Day: W, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room DB 1004, Day: W, Start: 12:50:00, End: 13:30:00
# Inserted free slot: Room DB 1004, Day: W, Start: 16:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 1004, Day: W, Start: 20:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 1004, Day: U
# Inserted room: DB 0005, ID: 3505
# Inserted full-day free slot: Room DB 0005, Day: F
# Inserted free slot: Room DB 0005, Day: T, Start: 08:30:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 0005, Day: T, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room DB 0005, Day: R, Start: 11:20:00, End: 14:30:00
# Inserted free slot: Room DB 0005, Day: R, Start: 17:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 0005, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room DB 0005, Day: M, Start: 08:30:00, End: 16:00:00
# Inserted free slot: Room DB 0005, Day: M, Start: 18:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 0005, Day: M, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0005, Day: S
# Inserted free slot: Room DB 0005, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0005, Day: W, Start: 14:20:00, End: 16:00:00
# Inserted free slot: Room DB 0005, Day: W, Start: 18:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 0005, Day: W, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0005, Day: U
# Inserted room: DB 1005, ID: 3506
# Inserted full-day free slot: Room DB 1005, Day: F
# Inserted free slot: Room DB 1005, Day: T, Start: 08:30:00, End: 14:00:00
# Inserted free slot: Room DB 1005, Day: T, Start: 16:50:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 1005, Day: T, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room DB 1005, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 1005, Day: R, Start: 14:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room DB 1005, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room DB 1005, Day: M, Start: 08:30:00, End: 16:00:00
# Inserted free slot: Room DB 1005, Day: M, Start: 18:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 1005, Day: M, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 1005, Day: S
# Inserted free slot: Room DB 1005, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room DB 1005, Day: W, Start: 17:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 1005, Day: W, Start: 20:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 1005, Day: U
# Inserted room: ACW 205, ID: 3507
# Inserted full-day free slot: Room ACW 205, Day: F
# Inserted free slot: Room ACW 205, Day: T, Start: 08:30:00, End: 16:00:00
# Inserted end-of-day free slot: Room ACW 205, Day: T, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room ACW 205, Day: R, Start: 08:30:00, End: 16:00:00
# Inserted end-of-day free slot: Room ACW 205, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room ACW 205, Day: M, Start: 08:30:00, End: 16:00:00
# Inserted end-of-day free slot: Room ACW 205, Day: M, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 205, Day: S
# Inserted full-day free slot: Room ACW 205, Day: W
# Inserted full-day free slot: Room ACW 205, Day: U
# Inserted room: DB 0016, ID: 3508
# Inserted full-day free slot: Room DB 0016, Day: F
# Inserted free slot: Room DB 0016, Day: T, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room DB 0016, Day: T, Start: 15:50:00, End: 16:00:00
# Inserted end-of-day free slot: Room DB 0016, Day: T, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room DB 0016, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room DB 0016, Day: R, Start: 15:50:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 0016, Day: R, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room DB 0016, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0016, Day: M, Start: 14:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 0016, Day: M, Start: 19:20:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0016, Day: S
# Inserted free slot: Room DB 0016, Day: W, Start: 08:30:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 0016, Day: W, Start: 19:20:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0016, Day: U
# Inserted room: CLH K, ID: 3509
# Inserted full-day free slot: Room CLH K, Day: F
# Inserted free slot: Room CLH K, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room CLH K, Day: T, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room CLH K, Day: T, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room CLH K, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room CLH K, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room CLH K, Day: M, Start: 11:20:00, End: 11:30:00
# Inserted end-of-day free slot: Room CLH K, Day: M, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room CLH K, Day: S
# Inserted free slot: Room CLH K, Day: W, Start: 11:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room CLH K, Day: W, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room CLH K, Day: U
# Inserted room: DB 0001, ID: 3510
# Inserted full-day free slot: Room DB 0001, Day: F
# Inserted free slot: Room DB 0001, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0001, Day: T, Start: 14:20:00, End: 14:30:00
# Inserted free slot: Room DB 0001, Day: T, Start: 15:50:00, End: 16:00:00
# Inserted end-of-day free slot: Room DB 0001, Day: T, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room DB 0001, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room DB 0001, Day: R, Start: 15:50:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 0001, Day: R, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room DB 0001, Day: M, Start: 08:30:00, End: 13:00:00
# Inserted free slot: Room DB 0001, Day: M, Start: 14:20:00, End: 17:30:00
# Inserted end-of-day free slot: Room DB 0001, Day: M, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0001, Day: S
# Inserted free slot: Room DB 0001, Day: W, Start: 08:30:00, End: 13:00:00
# Inserted free slot: Room DB 0001, Day: W, Start: 14:20:00, End: 17:30:00
# Inserted end-of-day free slot: Room DB 0001, Day: W, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0001, Day: U
# Inserted room: ACW 006, ID: 3511
# Inserted full-day free slot: Room ACW 006, Day: F
# Inserted full-day free slot: Room ACW 006, Day: T
# Inserted free slot: Room ACW 006, Day: R, Start: 08:30:00, End: 16:00:00
# Inserted end-of-day free slot: Room ACW 006, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 006, Day: M
# Inserted full-day free slot: Room ACW 006, Day: S
# Inserted full-day free slot: Room ACW 006, Day: W
# Inserted full-day free slot: Room ACW 006, Day: U
# Inserted room: DB 0007, ID: 3512
# Inserted full-day free slot: Room DB 0007, Day: F
# Inserted free slot: Room DB 0007, Day: T, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 0007, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room DB 0007, Day: R, Start: 08:30:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 0007, Day: R, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room DB 0007, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0007, Day: M, Start: 14:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 0007, Day: M, Start: 20:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0007, Day: S
# Inserted free slot: Room DB 0007, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0007, Day: W, Start: 14:20:00, End: 16:00:00
# Inserted free slot: Room DB 0007, Day: W, Start: 18:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 0007, Day: W, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0007, Day: U
# Inserted room: VH 1152A, ID: 3513
# Inserted full-day free slot: Room VH 1152A, Day: F
# Inserted free slot: Room VH 1152A, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room VH 1152A, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room VH 1152A, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room VH 1152A, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH 1152A, Day: M
# Inserted full-day free slot: Room VH 1152A, Day: S
# Inserted free slot: Room VH 1152A, Day: W, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room VH 1152A, Day: W, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room VH 1152A, Day: U
# Inserted room: CLH J, ID: 3514
# Inserted free slot: Room CLH J, Day: F, Start: 08:30:00, End: 10:00:00
# Inserted end-of-day free slot: Room CLH J, Day: F, Start: 12:50:00, End: 22:00:00
# Inserted free slot: Room CLH J, Day: T, Start: 08:30:00, End: 10:00:00
# Inserted end-of-day free slot: Room CLH J, Day: T, Start: 12:50:00, End: 22:00:00
# Inserted free slot: Room CLH J, Day: R, Start: 08:30:00, End: 16:00:00
# Inserted free slot: Room CLH J, Day: R, Start: 18:50:00, End: 19:00:00
# Inserted end-of-day free slot: Room CLH J, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room CLH J, Day: M, Start: 08:30:00, End: 09:00:00
# Inserted free slot: Room CLH J, Day: M, Start: 09:50:00, End: 17:00:00
# Inserted end-of-day free slot: Room CLH J, Day: M, Start: 17:50:00, End: 22:00:00
# Inserted full-day free slot: Room CLH J, Day: S
# Inserted free slot: Room CLH J, Day: W, Start: 08:30:00, End: 14:00:00
# Inserted free slot: Room CLH J, Day: W, Start: 14:50:00, End: 16:00:00
# Inserted end-of-day free slot: Room CLH J, Day: W, Start: 16:50:00, End: 22:00:00
# Inserted full-day free slot: Room CLH J, Day: U
# Inserted room: CLH H, ID: 3515
# Inserted full-day free slot: Room CLH H, Day: F
# Inserted free slot: Room CLH H, Day: T, Start: 08:30:00, End: 09:00:00
# Inserted free slot: Room CLH H, Day: T, Start: 09:50:00, End: 10:30:00
# Inserted free slot: Room CLH H, Day: T, Start: 14:20:00, End: 14:30:00
# Inserted free slot: Room CLH H, Day: T, Start: 16:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room CLH H, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room CLH H, Day: R, Start: 08:30:00, End: 10:30:00
# Inserted end-of-day free slot: Room CLH H, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room CLH H, Day: M, Start: 11:20:00, End: 11:30:00
# Inserted free slot: Room CLH H, Day: M, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room CLH H, Day: M, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room CLH H, Day: S
# Inserted free slot: Room CLH H, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room CLH H, Day: W, Start: 14:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room CLH H, Day: W, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room CLH H, Day: U
# Inserted room: R N203, ID: 3516
# Inserted full-day free slot: Room R N203, Day: F
# Inserted free slot: Room R N203, Day: T, Start: 11:20:00, End: 11:30:00
# Inserted free slot: Room R N203, Day: T, Start: 14:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room R N203, Day: T, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room R N203, Day: R, Start: 11:20:00, End: 11:30:00
# Inserted end-of-day free slot: Room R N203, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room R N203, Day: M, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room R N203, Day: M, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room R N203, Day: S
# Inserted free slot: Room R N203, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room R N203, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room R N203, Day: U
# Inserted room: ACW 106, ID: 3517
# Inserted full-day free slot: Room ACW 106, Day: F
# Inserted free slot: Room ACW 106, Day: T, Start: 08:30:00, End: 16:00:00
# Inserted end-of-day free slot: Room ACW 106, Day: T, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room ACW 106, Day: R, Start: 08:30:00, End: 14:00:00
# Inserted free slot: Room ACW 106, Day: R, Start: 14:50:00, End: 16:00:00
# Inserted end-of-day free slot: Room ACW 106, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 106, Day: M
# Inserted full-day free slot: Room ACW 106, Day: S
# Inserted full-day free slot: Room ACW 106, Day: W
# Inserted full-day free slot: Room ACW 106, Day: U
# Inserted room: ACW 002, ID: 3518
# Inserted full-day free slot: Room ACW 002, Day: F
# Inserted full-day free slot: Room ACW 002, Day: T
# Inserted free slot: Room ACW 002, Day: R, Start: 08:30:00, End: 11:00:00
# Inserted free slot: Room ACW 002, Day: R, Start: 11:50:00, End: 16:00:00
# Inserted end-of-day free slot: Room ACW 002, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 002, Day: M
# Inserted full-day free slot: Room ACW 002, Day: S
# Inserted free slot: Room ACW 002, Day: W, Start: 08:30:00, End: 18:00:00
# Inserted end-of-day free slot: Room ACW 002, Day: W, Start: 20:50:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 002, Day: U
# Inserted room: DB 0010, ID: 3519
# Inserted full-day free slot: Room DB 0010, Day: F
# Inserted free slot: Room DB 0010, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0010, Day: T, Start: 14:20:00, End: 14:30:00
# Inserted free slot: Room DB 0010, Day: T, Start: 17:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 0010, Day: T, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room DB 0010, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room DB 0010, Day: R, Start: 17:20:00, End: 19:00:00
# Inserted end-of-day free slot: Room DB 0010, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted free slot: Room DB 0010, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0010, Day: M, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room DB 0010, Day: M, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0010, Day: S
# Inserted free slot: Room DB 0010, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0010, Day: W, Start: 14:20:00, End: 14:30:00
# Inserted free slot: Room DB 0010, Day: W, Start: 17:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room DB 0010, Day: W, Start: 20:50:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0010, Day: U
# Inserted room: HNE 030, ID: 3520
# Inserted full-day free slot: Room HNE 030, Day: F
# Inserted full-day free slot: Room HNE 030, Day: T
# Inserted free slot: Room HNE 030, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room HNE 030, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room HNE 030, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room HNE 030, Day: M, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room HNE 030, Day: S
# Inserted full-day free slot: Room HNE 030, Day: W
# Inserted full-day free slot: Room HNE 030, Day: U
# Inserted room: HNE 036, ID: 3521
# Inserted full-day free slot: Room HNE 036, Day: F
# Inserted full-day free slot: Room HNE 036, Day: T
# Inserted free slot: Room HNE 036, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room HNE 036, Day: R, Start: 14:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room HNE 036, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room HNE 036, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room HNE 036, Day: M, Start: 14:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room HNE 036, Day: M, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room HNE 036, Day: S
# Inserted full-day free slot: Room HNE 036, Day: W
# Inserted full-day free slot: Room HNE 036, Day: U
# Inserted room: VH 2043, ID: 3522
# Inserted full-day free slot: Room VH 2043, Day: F
# Inserted free slot: Room VH 2043, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room VH 2043, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room VH 2043, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room VH 2043, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room VH 2043, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room VH 2043, Day: M, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH 2043, Day: S
# Inserted free slot: Room VH 2043, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room VH 2043, Day: W, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH 2043, Day: U
# Inserted room: VH 3005, ID: 3523
# Inserted full-day free slot: Room VH 3005, Day: F
# Inserted full-day free slot: Room VH 3005, Day: T
# Inserted full-day free slot: Room VH 3005, Day: R
# Inserted free slot: Room VH 3005, Day: M, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room VH 3005, Day: M, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH 3005, Day: S
# Inserted free slot: Room VH 3005, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room VH 3005, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH 3005, Day: U
# Inserted room: VH 3004, ID: 3524
# Inserted full-day free slot: Room VH 3004, Day: F
# Inserted end-of-day free slot: Room VH 3004, Day: T, Start: 11:20:00, End: 22:00:00
# Inserted end-of-day free slot: Room VH 3004, Day: R, Start: 11:20:00, End: 22:00:00
# Inserted end-of-day free slot: Room VH 3004, Day: M, Start: 11:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH 3004, Day: S
# Inserted end-of-day free slot: Room VH 3004, Day: W, Start: 11:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH 3004, Day: U
# Inserted room: MC 157C, ID: 3525
# Invalid schedule entry for room MC 157C. Skipping: {'course': {'faculty': 'ED', 'dept': 'AUCO', 'code': '3565', 'credit': 3.0}, 'section': 'A', 'term': 'BS', 'title': 'BLEN 01', 'day': '', 'time': '', 'duration': '0'}
# Inserted full-day free slot: Room MC 157C, Day: F
# Inserted full-day free slot: Room MC 157C, Day: T
# Inserted full-day free slot: Room MC 157C, Day: R
# Inserted full-day free slot: Room MC 157C, Day: M
# Inserted full-day free slot: Room MC 157C, Day: S
# Inserted full-day free slot: Room MC 157C, Day: W
# Inserted full-day free slot: Room MC 157C, Day: U
# Inserted room: LAS C, ID: 3526
# Inserted full-day free slot: Room LAS C, Day: F
# Inserted free slot: Room LAS C, Day: T, Start: 11:20:00, End: 13:00:00
# Inserted free slot: Room LAS C, Day: T, Start: 15:50:00, End: 17:30:00
# Inserted end-of-day free slot: Room LAS C, Day: T, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room LAS C, Day: R, Start: 11:20:00, End: 13:00:00
# Inserted free slot: Room LAS C, Day: R, Start: 15:50:00, End: 17:30:00
# Inserted end-of-day free slot: Room LAS C, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room LAS C, Day: M, Start: 08:30:00, End: 09:00:00
# Inserted free slot: Room LAS C, Day: M, Start: 10:20:00, End: 10:30:00
# Inserted free slot: Room LAS C, Day: M, Start: 11:50:00, End: 12:00:00
# Inserted end-of-day free slot: Room LAS C, Day: M, Start: 13:20:00, End: 22:00:00
# Inserted full-day free slot: Room LAS C, Day: S
# Inserted free slot: Room LAS C, Day: W, Start: 08:30:00, End: 09:00:00
# Inserted free slot: Room LAS C, Day: W, Start: 10:20:00, End: 10:30:00
# Inserted free slot: Room LAS C, Day: W, Start: 11:50:00, End: 12:00:00
# Inserted end-of-day free slot: Room LAS C, Day: W, Start: 13:20:00, End: 22:00:00
# Inserted full-day free slot: Room LAS C, Day: U
# Inserted room: ACW 206, ID: 3527
# Inserted free slot: Room ACW 206, Day: F, Start: 08:30:00, End: 12:30:00
# Inserted end-of-day free slot: Room ACW 206, Day: F, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room ACW 206, Day: T, Start: 08:30:00, End: 10:00:00
# Inserted end-of-day free slot: Room ACW 206, Day: T, Start: 12:50:00, End: 22:00:00
# Inserted free slot: Room ACW 206, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room ACW 206, Day: R, Start: 12:50:00, End: 16:00:00
# Inserted end-of-day free slot: Room ACW 206, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room ACW 206, Day: M, Start: 08:30:00, End: 12:30:00
# Inserted end-of-day free slot: Room ACW 206, Day: M, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 206, Day: S
# Inserted free slot: Room ACW 206, Day: W, Start: 08:30:00, End: 12:30:00
# Inserted end-of-day free slot: Room ACW 206, Day: W, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room ACW 206, Day: U
# Inserted room: LSB 103, ID: 3528
# Inserted full-day free slot: Room LSB 103, Day: F
# Inserted free slot: Room LSB 103, Day: T, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room LSB 103, Day: T, Start: 12:50:00, End: 13:00:00
# Inserted end-of-day free slot: Room LSB 103, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room LSB 103, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room LSB 103, Day: R, Start: 12:50:00, End: 13:00:00
# Inserted free slot: Room LSB 103, Day: R, Start: 14:20:00, End: 17:30:00
# Inserted end-of-day free slot: Room LSB 103, Day: R, Start: 19:20:00, End: 22:00:00
# Inserted free slot: Room LSB 103, Day: M, Start: 08:30:00, End: 10:00:00
# Inserted end-of-day free slot: Room LSB 103, Day: M, Start: 12:50:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 103, Day: S
# Inserted free slot: Room LSB 103, Day: W, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room LSB 103, Day: W, Start: 12:50:00, End: 16:00:00
# Inserted end-of-day free slot: Room LSB 103, Day: W, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 103, Day: U
# Inserted room: LAS A, ID: 3529
# Inserted free slot: Room LAS A, Day: F, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room LAS A, Day: F, Start: 13:20:00, End: 13:30:00
# Inserted end-of-day free slot: Room LAS A, Day: F, Start: 15:20:00, End: 22:00:00
# Inserted free slot: Room LAS A, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room LAS A, Day: T, Start: 13:50:00, End: 22:00:00
# Inserted free slot: Room LAS A, Day: R, Start: 08:30:00, End: 10:30:00
# Inserted end-of-day free slot: Room LAS A, Day: R, Start: 11:20:00, End: 22:00:00
# Inserted free slot: Room LAS A, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room LAS A, Day: M, Start: 15:20:00, End: 22:00:00
# Inserted full-day free slot: Room LAS A, Day: S
# Inserted free slot: Room LAS A, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room LAS A, Day: W, Start: 15:20:00, End: 16:30:00
# Inserted end-of-day free slot: Room LAS A, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LAS A, Day: U
# Inserted room: LSB 219, ID: 3530
# Inserted full-day free slot: Room LSB 219, Day: F
# Inserted free slot: Room LSB 219, Day: T, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 219, Day: T, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room LSB 219, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 219, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 219, Day: M
# Inserted full-day free slot: Room LSB 219, Day: S
# Inserted free slot: Room LSB 219, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 219, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 219, Day: U
# Inserted room: LSB 221, ID: 3531
# Inserted full-day free slot: Room LSB 221, Day: F
# Inserted free slot: Room LSB 221, Day: T, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 221, Day: T, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room LSB 221, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 221, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 221, Day: M
# Inserted full-day free slot: Room LSB 221, Day: S
# Inserted free slot: Room LSB 221, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 221, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 221, Day: U
# Inserted room: LSB 215, ID: 3532
# Inserted full-day free slot: Room LSB 215, Day: F
# Inserted full-day free slot: Room LSB 215, Day: T
# Inserted free slot: Room LSB 215, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room LSB 215, Day: R, Start: 12:50:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 215, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 215, Day: M
# Inserted full-day free slot: Room LSB 215, Day: S
# Inserted free slot: Room LSB 215, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 215, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 215, Day: U
# Inserted room: LSB 217, ID: 3533
# Inserted full-day free slot: Room LSB 217, Day: F
# Inserted full-day free slot: Room LSB 217, Day: T
# Inserted free slot: Room LSB 217, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room LSB 217, Day: R, Start: 12:50:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 217, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 217, Day: M
# Inserted full-day free slot: Room LSB 217, Day: S
# Inserted free slot: Room LSB 217, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 217, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 217, Day: U
# Inserted room: LSB 105, ID: 3534
# Inserted free slot: Room LSB 105, Day: F, Start: 09:20:00, End: 13:00:00
# Inserted end-of-day free slot: Room LSB 105, Day: F, Start: 13:50:00, End: 22:00:00
# Inserted free slot: Room LSB 105, Day: T, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room LSB 105, Day: T, Start: 11:20:00, End: 13:00:00
# Inserted end-of-day free slot: Room LSB 105, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room LSB 105, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room LSB 105, Day: R, Start: 11:20:00, End: 13:00:00
# Inserted end-of-day free slot: Room LSB 105, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room LSB 105, Day: M, Start: 09:20:00, End: 13:00:00
# Inserted free slot: Room LSB 105, Day: M, Start: 13:50:00, End: 18:30:00
# Inserted end-of-day free slot: Room LSB 105, Day: M, Start: 21:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 105, Day: S
# Inserted free slot: Room LSB 105, Day: W, Start: 09:20:00, End: 13:00:00
# Inserted free slot: Room LSB 105, Day: W, Start: 13:50:00, End: 18:30:00
# Inserted end-of-day free slot: Room LSB 105, Day: W, Start: 21:20:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 105, Day: U
# Inserted room: LUM 124, ID: 3535
# Inserted full-day free slot: Room LUM 124, Day: F
# Inserted free slot: Room LUM 124, Day: T, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LUM 124, Day: T, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room LUM 124, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room LUM 124, Day: R, Start: 12:50:00, End: 14:30:00
# Inserted end-of-day free slot: Room LUM 124, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LUM 124, Day: M
# Inserted full-day free slot: Room LUM 124, Day: S
# Inserted free slot: Room LUM 124, Day: W, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room LUM 124, Day: W, Start: 12:50:00, End: 14:30:00
# Inserted end-of-day free slot: Room LUM 124, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room LUM 124, Day: U
# Inserted room: LAS B, ID: 3536
# Inserted full-day free slot: Room LAS B, Day: F
# Inserted free slot: Room LAS B, Day: T, Start: 08:30:00, End: 17:30:00
# Inserted end-of-day free slot: Room LAS B, Day: T, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room LAS B, Day: R, Start: 08:30:00, End: 17:30:00
# Inserted end-of-day free slot: Room LAS B, Day: R, Start: 18:50:00, End: 22:00:00
# Inserted free slot: Room LAS B, Day: M, Start: 09:50:00, End: 10:00:00
# Inserted free slot: Room LAS B, Day: M, Start: 11:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room LAS B, Day: M, Start: 15:50:00, End: 22:00:00
# Inserted full-day free slot: Room LAS B, Day: S
# Inserted free slot: Room LAS B, Day: W, Start: 09:50:00, End: 10:00:00
# Inserted free slot: Room LAS B, Day: W, Start: 11:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room LAS B, Day: W, Start: 15:50:00, End: 22:00:00
# Inserted full-day free slot: Room LAS B, Day: U
# Inserted room: CB 120, ID: 3537
# Inserted full-day free slot: Room CB 120, Day: F
# Inserted free slot: Room CB 120, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room CB 120, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room CB 120, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room CB 120, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room CB 120, Day: M, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room CB 120, Day: M, Start: 11:20:00, End: 11:30:00
# Inserted free slot: Room CB 120, Day: M, Start: 12:50:00, End: 13:00:00
# Inserted free slot: Room CB 120, Day: M, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room CB 120, Day: M, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room CB 120, Day: S
# Inserted free slot: Room CB 120, Day: W, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room CB 120, Day: W, Start: 11:20:00, End: 11:30:00
# Inserted free slot: Room CB 120, Day: W, Start: 12:50:00, End: 13:00:00
# Inserted free slot: Room CB 120, Day: W, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room CB 120, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room CB 120, Day: U
# Inserted room: LSB 101, ID: 3538
# Inserted full-day free slot: Room LSB 101, Day: F
# Inserted full-day free slot: Room LSB 101, Day: T
# Inserted free slot: Room LSB 101, Day: R, Start: 08:30:00, End: 18:00:00
# Inserted end-of-day free slot: Room LSB 101, Day: R, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room LSB 101, Day: M, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room LSB 101, Day: M, Start: 15:50:00, End: 22:00:00
# Inserted full-day free slot: Room LSB 101, Day: S
# Inserted full-day free slot: Room LSB 101, Day: W
# Inserted full-day free slot: Room LSB 101, Day: U
# Inserted room: FRQ 124, ID: 3539
# Inserted full-day free slot: Room FRQ 124, Day: F
# Inserted free slot: Room FRQ 124, Day: T, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room FRQ 124, Day: T, Start: 12:50:00, End: 14:30:00
# Inserted end-of-day free slot: Room FRQ 124, Day: T, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room FRQ 124, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted free slot: Room FRQ 124, Day: R, Start: 12:50:00, End: 14:30:00
# Inserted end-of-day free slot: Room FRQ 124, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room FRQ 124, Day: M
# Inserted full-day free slot: Room FRQ 124, Day: S
# Inserted full-day free slot: Room FRQ 124, Day: W
# Inserted full-day free slot: Room FRQ 124, Day: U
# Inserted room: FRQ 120, ID: 3540
# Inserted full-day free slot: Room FRQ 120, Day: F
# Inserted free slot: Room FRQ 120, Day: T, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room FRQ 120, Day: T, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room FRQ 120, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room FRQ 120, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room FRQ 120, Day: M
# Inserted full-day free slot: Room FRQ 120, Day: S
# Inserted full-day free slot: Room FRQ 120, Day: W
# Inserted full-day free slot: Room FRQ 120, Day: U
# Inserted room: FRQ 122, ID: 3541
# Inserted full-day free slot: Room FRQ 122, Day: F
# Inserted free slot: Room FRQ 122, Day: T, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room FRQ 122, Day: T, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room FRQ 122, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room FRQ 122, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room FRQ 122, Day: M
# Inserted full-day free slot: Room FRQ 122, Day: S
# Inserted full-day free slot: Room FRQ 122, Day: W
# Inserted full-day free slot: Room FRQ 122, Day: U
# Inserted room: LUM 109, ID: 3542
# Inserted full-day free slot: Room LUM 109, Day: F
# Inserted free slot: Room LUM 109, Day: T, Start: 08:30:00, End: 10:00:00
# Inserted end-of-day free slot: Room LUM 109, Day: T, Start: 12:50:00, End: 22:00:00
# Inserted free slot: Room LUM 109, Day: R, Start: 08:30:00, End: 10:00:00
# Inserted end-of-day free slot: Room LUM 109, Day: R, Start: 12:50:00, End: 22:00:00
# Inserted free slot: Room LUM 109, Day: M, Start: 08:30:00, End: 10:00:00
# Inserted end-of-day free slot: Room LUM 109, Day: M, Start: 12:50:00, End: 22:00:00
# Inserted full-day free slot: Room LUM 109, Day: S
# Inserted free slot: Room LUM 109, Day: W, Start: 08:30:00, End: 10:00:00
# Inserted end-of-day free slot: Room LUM 109, Day: W, Start: 12:50:00, End: 22:00:00
# Inserted full-day free slot: Room LUM 109, Day: U
# Inserted room: LUM 110, ID: 3543
# Inserted full-day free slot: Room LUM 110, Day: F
# Inserted free slot: Room LUM 110, Day: T, Start: 08:30:00, End: 14:30:00
# ...
# Inserted full-day free slot: Room BC 102F, Day: S
# Inserted full-day free slot: Room BC 102F, Day: W
# Inserted full-day free slot: Room BC 102F, Day: U
# Building not found for code TM. Skipping room TM POOL.
# Building not found for code TM. Skipping room TM UPPGYM.
# Building not found for code TM. Skipping room TM MNGYM.
# Building not found for code TM. Skipping room TM STUDIO2.
# Building not found for code TM. Skipping room TM STUDIO6.
# Building not found for code TM. Skipping room TM STUDIO4.
# Inserted room: TFC 115B, ID: 3650
# Inserted full-day free slot: Room TFC 115B, Day: F
# Inserted free slot: Room TFC 115B, Day: T, Start: 08:30:00, End: 09:30:00
# Inserted free slot: Room TFC 115B, Day: T, Start: 11:20:00, End: 11:30:00
# Inserted end-of-day free slot: Room TFC 115B, Day: T, Start: 13:20:00, End: 22:00:00
# Inserted free slot: Room TFC 115B, Day: R, Start: 08:30:00, End: 09:30:00
# Inserted free slot: Room TFC 115B, Day: R, Start: 11:20:00, End: 11:30:00
# Inserted end-of-day free slot: Room TFC 115B, Day: R, Start: 13:20:00, End: 22:00:00
# Inserted free slot: Room TFC 115B, Day: M, Start: 08:30:00, End: 09:30:00
# Inserted end-of-day free slot: Room TFC 115B, Day: M, Start: 11:20:00, End: 22:00:00
# Inserted full-day free slot: Room TFC 115B, Day: S
# Inserted free slot: Room TFC 115B, Day: W, Start: 08:30:00, End: 09:30:00
# Inserted end-of-day free slot: Room TFC 115B, Day: W, Start: 11:20:00, End: 22:00:00
# Inserted full-day free slot: Room TFC 115B, Day: U
# Inserted room: TFC 115A, ID: 3651
# Inserted full-day free slot: Room TFC 115A, Day: F
# Inserted free slot: Room TFC 115A, Day: T, Start: 08:30:00, End: 09:30:00
# Inserted free slot: Room TFC 115A, Day: T, Start: 11:20:00, End: 11:30:00
# Inserted end-of-day free slot: Room TFC 115A, Day: T, Start: 13:20:00, End: 22:00:00
# Inserted free slot: Room TFC 115A, Day: R, Start: 08:30:00, End: 09:30:00
# Inserted free slot: Room TFC 115A, Day: R, Start: 11:20:00, End: 11:30:00
# Inserted end-of-day free slot: Room TFC 115A, Day: R, Start: 13:20:00, End: 22:00:00
# Inserted free slot: Room TFC 115A, Day: M, Start: 08:30:00, End: 09:30:00
# Inserted free slot: Room TFC 115A, Day: M, Start: 11:20:00, End: 11:30:00
# Inserted end-of-day free slot: Room TFC 115A, Day: M, Start: 13:20:00, End: 22:00:00
# Inserted full-day free slot: Room TFC 115A, Day: S
# Inserted free slot: Room TFC 115A, Day: W, Start: 08:30:00, End: 09:30:00
# Inserted free slot: Room TFC 115A, Day: W, Start: 11:20:00, End: 11:30:00
# Inserted end-of-day free slot: Room TFC 115A, Day: W, Start: 13:20:00, End: 22:00:00
# Inserted full-day free slot: Room TFC 115A, Day: U
# Inserted room: SC 101A, ID: 3652
# Inserted full-day free slot: Room SC 101A, Day: F
# Inserted free slot: Room SC 101A, Day: T, Start: 10:20:00, End: 10:30:00
# Inserted free slot: Room SC 101A, Day: T, Start: 12:20:00, End: 12:30:00
# Inserted end-of-day free slot: Room SC 101A, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room SC 101A, Day: R, Start: 10:20:00, End: 10:30:00
# Inserted free slot: Room SC 101A, Day: R, Start: 12:20:00, End: 12:30:00
# Inserted end-of-day free slot: Room SC 101A, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room SC 101A, Day: M, Start: 10:20:00, End: 10:30:00
# Inserted free slot: Room SC 101A, Day: M, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room SC 101A, Day: M, Start: 16:20:00, End: 22:00:00
# Inserted full-day free slot: Room SC 101A, Day: S
# Inserted free slot: Room SC 101A, Day: W, Start: 10:20:00, End: 10:30:00
# Inserted free slot: Room SC 101A, Day: W, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room SC 101A, Day: W, Start: 16:20:00, End: 22:00:00
# Inserted full-day free slot: Room SC 101A, Day: U
# Inserted room: HNE 031, ID: 3653
# Inserted full-day free slot: Room HNE 031, Day: F
# Inserted free slot: Room HNE 031, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room HNE 031, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room HNE 031, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room HNE 031, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room HNE 031, Day: M
# Inserted full-day free slot: Room HNE 031, Day: S
# Inserted full-day free slot: Room HNE 031, Day: W
# Inserted full-day free slot: Room HNE 031, Day: U
# Inserted room: DB 0009, ID: 3654
# Inserted free slot: Room DB 0009, Day: F, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room DB 0009, Day: F, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room DB 0009, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room DB 0009, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room DB 0009, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room DB 0009, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room DB 0009, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0009, Day: M, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room DB 0009, Day: M, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0009, Day: S
# Inserted free slot: Room DB 0009, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room DB 0009, Day: W, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room DB 0009, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0009, Day: U
# Inserted room: R S127, ID: 3655
# Inserted full-day free slot: Room R S127, Day: F
# Inserted free slot: Room R S127, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room R S127, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room R S127, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room R S127, Day: R, Start: 14:20:00, End: 22:00:00
# Inserted free slot: Room R S127, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room R S127, Day: M, Start: 14:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room R S127, Day: M, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room R S127, Day: S
# Inserted free slot: Room R S127, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room R S127, Day: W, Start: 14:20:00, End: 16:00:00
# Inserted end-of-day free slot: Room R S127, Day: W, Start: 18:50:00, End: 22:00:00
# Inserted full-day free slot: Room R S127, Day: U
# Building not found for code MK. Skipping room MK 5050.
# Inserted room: R S501, ID: 3656
# Inserted full-day free slot: Room R S501, Day: F
# Inserted full-day free slot: Room R S501, Day: T
# Inserted free slot: Room R S501, Day: R, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room R S501, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room R S501, Day: M
# Inserted full-day free slot: Room R S501, Day: S
# Inserted full-day free slot: Room R S501, Day: W
# Inserted full-day free slot: Room R S501, Day: U
# Inserted room: BSB 204, ID: 3657
# Inserted free slot: Room BSB 204, Day: F, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room BSB 204, Day: F, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room BSB 204, Day: T
# Inserted full-day free slot: Room BSB 204, Day: R
# Inserted full-day free slot: Room BSB 204, Day: M
# Inserted full-day free slot: Room BSB 204, Day: S
# Inserted free slot: Room BSB 204, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room BSB 204, Day: W, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room BSB 204, Day: U
# Inserted room: BSB 203, ID: 3658
# Inserted full-day free slot: Room BSB 203, Day: F
# Inserted full-day free slot: Room BSB 203, Day: T
# Inserted full-day free slot: Room BSB 203, Day: R
# Inserted full-day free slot: Room BSB 203, Day: M
# Inserted full-day free slot: Room BSB 203, Day: S
# Inserted free slot: Room BSB 203, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room BSB 203, Day: W, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room BSB 203, Day: U
# Inserted room: FC 203, ID: 3659
# Inserted full-day free slot: Room FC 203, Day: F
# Inserted full-day free slot: Room FC 203, Day: T
# Inserted full-day free slot: Room FC 203, Day: R
# Inserted free slot: Room FC 203, Day: M, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room FC 203, Day: M, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room FC 203, Day: S
# Inserted free slot: Room FC 203, Day: W, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room FC 203, Day: W, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room FC 203, Day: U
# Inserted room: R N141, ID: 3660
# Inserted full-day free slot: Room R N141, Day: F
# Inserted full-day free slot: Room R N141, Day: T
# Inserted full-day free slot: Room R N141, Day: R
# Inserted free slot: Room R N141, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room R N141, Day: M, Start: 14:30:00, End: 22:00:00
# Inserted full-day free slot: Room R N141, Day: S
# Inserted free slot: Room R N141, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room R N141, Day: W, Start: 14:30:00, End: 22:00:00
# Inserted full-day free slot: Room R N141, Day: U
# Inserted room: R S103, ID: 3661
# Inserted full-day free slot: Room R S103, Day: F
# Inserted free slot: Room R S103, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room R S103, Day: T, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room R S103, Day: T, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room R S103, Day: R, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room R S103, Day: R, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room R S103, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room R S103, Day: M, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room R S103, Day: M, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room R S103, Day: M, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room R S103, Day: S
# Inserted free slot: Room R S103, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted free slot: Room R S103, Day: W, Start: 14:20:00, End: 14:30:00
# Inserted end-of-day free slot: Room R S103, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room R S103, Day: U
# Inserted room: DB 0015, ID: 3662
# Inserted full-day free slot: Room DB 0015, Day: F
# Inserted free slot: Room DB 0015, Day: T, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room DB 0015, Day: T, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room DB 0015, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room DB 0015, Day: R, Start: 17:20:00, End: 22:00:00
# Inserted free slot: Room DB 0015, Day: M, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room DB 0015, Day: M, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0015, Day: S
# Inserted free slot: Room DB 0015, Day: W, Start: 08:30:00, End: 14:30:00
# Inserted end-of-day free slot: Room DB 0015, Day: W, Start: 17:20:00, End: 22:00:00
# Inserted full-day free slot: Room DB 0015, Day: U
# Inserted room: VH 1152, ID: 3663
# Inserted full-day free slot: Room VH 1152, Day: F
# Inserted free slot: Room VH 1152, Day: T, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room VH 1152, Day: T, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH 1152, Day: R
# Inserted full-day free slot: Room VH 1152, Day: M
# Inserted full-day free slot: Room VH 1152, Day: S
# Inserted free slot: Room VH 1152, Day: W, Start: 08:30:00, End: 11:30:00
# Inserted end-of-day free slot: Room VH 1152, Day: W, Start: 14:20:00, End: 22:00:00
# Inserted full-day free slot: Room VH 1152, Day: U
# Inserted room: R S803, ID: 3664
# Inserted full-day free slot: Room R S803, Day: F
# Inserted free slot: Room R S803, Day: T, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room R S803, Day: T, Start: 17:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room R S803, Day: T, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room R S803, Day: R, Start: 08:30:00, End: 18:00:00
# Inserted end-of-day free slot: Room R S803, Day: R, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room R S803, Day: M, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room R S803, Day: M, Start: 17:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room R S803, Day: M, Start: 20:50:00, End: 22:00:00
# Inserted full-day free slot: Room R S803, Day: S
# Inserted free slot: Room R S803, Day: W, Start: 08:30:00, End: 18:00:00
# Inserted end-of-day free slot: Room R S803, Day: W, Start: 20:50:00, End: 22:00:00
# Inserted full-day free slot: Room R S803, Day: U
# Inserted room: R S801, ID: 3665
# Inserted full-day free slot: Room R S801, Day: F
# Inserted free slot: Room R S801, Day: T, Start: 08:30:00, End: 11:00:00
# Inserted free slot: Room R S801, Day: T, Start: 13:50:00, End: 14:30:00
# Inserted free slot: Room R S801, Day: T, Start: 17:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room R S801, Day: T, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room R S801, Day: R, Start: 08:30:00, End: 14:30:00
# Inserted free slot: Room R S801, Day: R, Start: 17:20:00, End: 18:00:00
# Inserted end-of-day free slot: Room R S801, Day: R, Start: 20:50:00, End: 22:00:00
# Inserted free slot: Room R S801, Day: M, Start: 08:30:00, End: 11:00:00
# Inserted end-of-day free slot: Room R S801, Day: M, Start: 13:50:00, End: 22:00:00
# Inserted full-day free slot: Room R S801, Day: S
# Inserted full-day free slot: Room R S801, Day: W
# Inserted full-day free slot: Room R S801, Day: U
# Inserted room: SSB S124, ID: 3666
# Inserted full-day free slot: Room SSB S124, Day: F
# Inserted full-day free slot: Room SSB S124, Day: T
# Inserted free slot: Room SSB S124, Day: R, Start: 08:30:00, End: 19:00:00
# Inserted end-of-day free slot: Room SSB S124, Day: R, Start: 21:50:00, End: 22:00:00
# Inserted full-day free slot: Room SSB S124, Day: M
# Inserted full-day free slot: Room SSB S124, Day: S
# Inserted full-day free slot: Room SSB S124, Day: W
# Inserted full-day free slot: Room SSB S124, Day: U
# Inserted room: CFT 138, ID: 3667
# Inserted full-day free slot: Room CFT 138, Day: F
# Inserted free slot: Room CFT 138, Day: T, Start: 08:30:00, End: 11:00:00
# Inserted end-of-day free slot: Room CFT 138, Day: T, Start: 16:50:00, End: 22:00:00
# Inserted free slot: Room CFT 138, Day: R, Start: 08:30:00, End: 11:00:00
# Inserted end-of-day free slot: Room CFT 138, Day: R, Start: 16:50:00, End: 22:00:00
# Inserted full-day free slot: Room CFT 138, Day: M
# Inserted full-day free slot: Room CFT 138, Day: S
# Inserted full-day free slot: Room CFT 138, Day: W
# Inserted full-day free slot: Room CFT 138, Day: U
# Inserted room: CFA 284, ID: 3668
# Inserted full-day free slot: Room CFA 284, Day: F
# Inserted free slot: Room CFA 284, Day: T, Start: 08:30:00, End: 09:00:00
# Inserted end-of-day free slot: Room CFA 284, Day: T, Start: 13:10:00, End: 22:00:00
# Inserted free slot: Room CFA 284, Day: R, Start: 08:30:00, End: 09:00:00
# Inserted end-of-day free slot: Room CFA 284, Day: R, Start: 13:10:00, End: 22:00:00
# Inserted free slot: Room CFA 284, Day: M, Start: 08:30:00, End: 09:00:00
# Inserted end-of-day free slot: Room CFA 284, Day: M, Start: 13:10:00, End: 22:00:00
# Inserted full-day free slot: Room CFA 284, Day: S
# Inserted full-day free slot: Room CFA 284, Day: W
# Inserted full-day free slot: Room CFA 284, Day: U
# Inserted room: CFA 004, ID: 3669
# Inserted full-day free slot: Room CFA 004, Day: F
# Inserted free slot: Room CFA 004, Day: T, Start: 08:30:00, End: 09:30:00
# Inserted end-of-day free slot: Room CFA 004, Day: T, Start: 13:10:00, End: 22:00:00
# Inserted full-day free slot: Room CFA 004, Day: R
# Inserted free slot: Room CFA 004, Day: M, Start: 08:30:00, End: 09:30:00
# Inserted end-of-day free slot: Room CFA 004, Day: M, Start: 13:10:00, End: 22:00:00
# Inserted full-day free slot: Room CFA 004, Day: S
# Inserted free slot: Room CFA 004, Day: W, Start: 08:30:00, End: 09:30:00
# Inserted end-of-day free slot: Room CFA 004, Day: W, Start: 13:10:00, End: 22:00:00
# Inserted full-day free slot: Room CFA 004, Day: U
# ✅ Rooms and availabilities loaded successfully.

# %% [markdown]
# # Updating the availability everymonth.

# %% [markdown]
# # Testing Cafes and Libraries

# %%
import sys
import os

import mysql.connector
from mysql.connector import Error
import json
from datetime import datetime, timedelta

# Add the project root to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

from app.database import get_cafes, get_libraries, get_lecture_halls

cafes = get_cafes()

print(cafes)

libraries = get_libraries()

print(libraries)

lecture_halls = get_lecture_halls()

print(lecture_halls)
# Out:
# Starting get_cafes function...
# Database connection closed.
# [{'building': 'Aroma Espresso Bar - Pond', 'location': (-79.50186839999999, 43.7734535), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:30', 'EndTime': '22:00', 'Status': []}]}, {'building': 'Aroma Espresso Bar - York Lanes', 'location': (-79.5018478, 43.7742143), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:30', 'EndTime': '21:00', 'Status': []}]}, {'building': 'Break Cafe - Second Student Center', 'location': (-79.503864, 43.7715346), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '20:00', 'Status': []}]}, {'building': 'La Prep - York Lanes', 'location': (-79.5018478, 43.7742143), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '21:00', 'Status': []}]}, {'building': 'Schulich Market Cafe - Schulich School of Business', 'location': (-79.498257, 43.773227), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:00', 'EndTime': '21:00', 'Status': []}]}, {'building': 'Starbucks - ACW', 'location': (-79.3831843, 43.653226), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:30', 'EndTime': '21:00', 'Status': []}]}, {'building': 'Starbucks - Central Square', 'location': (-79.50489999999999, 43.7728891), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '19:00', 'Status': []}]}, {'building': 'The Great Canadian Bagel - York Lanes', 'location': (-79.5018478, 43.7742143), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '19:00', 'Status': []}]}, {'building': 'Tim Hortons - Central Square', 'location': (-79.50436359999999, 43.7721373), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:30', 'EndTime': '20:00', 'Status': []}]}, {'building': 'Tim Hortons - William Small Center', 'location': (-79.50777769999999, 43.77294500000001), 'building_code': '', 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '07:00', 'EndTime': '18:00', 'Status': []}]}]
# Starting get_libraries function...
# Database connection closed.
# [{'building': 'Bronfman Business Library', 'location': (-79.4987993, 43.7734232), 'building_code': '', 'website': None, 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '21:00', 'Status': ''}]}, {'building': 'Scott Library', 'location': (-79.5055508, 43.7723418), 'building_code': '', 'website': None, 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '23:00', 'Status': ''}]}, {'building': 'Steacie Science and Engineering Library', 'location': (-79.505845, 43.773608), 'building_code': '', 'website': None, 'building_status': '', 'rooms': {}, 'slots': [{'StartTime': '08:00', 'EndTime': '21:00', 'Status': ''}]}]
# Starting get_lecture_halls function...
# Lec Halls, Database connection closed.
# [{'building': 'Accolade Building East', 'building_code': 'ACE', 'location': (-79.4993904, 43.7725551), 'building_status': '', 'rooms': {'ACE 001': {'roomNumber': 'ACE 001', 'slots': [{'StartTime': '15:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 002': {'roomNumber': 'ACE 002', 'slots': [{'StartTime': '10:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '17:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 003': {'roomNumber': 'ACE 003', 'slots': [{'StartTime': '08:30', 'EndTime': '09:30', 'Status': ''}, {'StartTime': '19:00', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 004': {'roomNumber': 'ACE 004', 'slots': [{'StartTime': '09:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 005': {'roomNumber': 'ACE 005', 'slots': [{'StartTime': '08:30', 'EndTime': '09:30', 'Status': ''}, {'StartTime': '19:00', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 006': {'roomNumber': 'ACE 006', 'slots': [{'StartTime': '08:30', 'EndTime': '10:30', 'Status': ''}, {'StartTime': '16:00', 'EndTime': '16:30', 'Status': ''}, {'StartTime': '18:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 007': {'roomNumber': 'ACE 007', 'slots': [{'StartTime': '08:30', 'EndTime': '09:30', 'Status': ''}, {'StartTime': '10:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '19:00', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 008': {'roomNumber': 'ACE 008', 'slots': [{'StartTime': '17:30', 'EndTime': '18:00', 'Status': ''}, {'StartTime': '20:00', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 009': {'roomNumber': 'ACE 009', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:30', 'EndTime': '16:00', 'Status': ''}, {'StartTime': '19:00', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 010': {'roomNumber': 'ACE 010', 'slots': [{'StartTime': '08:30', 'EndTime': '10:30', 'Status': ''}, {'StartTime': '17:30', 'EndTime': '18:00', 'Status': ''}, {'StartTime': '20:00', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 011': {'roomNumber': 'ACE 011', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '19:00', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 012': {'roomNumber': 'ACE 012', 'slots': [{'StartTime': '08:30', 'EndTime': '09:30', 'Status': ''}, {'StartTime': '17:30', 'EndTime': '18:00', 'Status': ''}, {'StartTime': '20:00', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 013': {'roomNumber': 'ACE 013', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '14:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 021': {'roomNumber': 'ACE 021', 'slots': [{'StartTime': '08:30', 'EndTime': '11:30', 'Status': ''}, {'StartTime': '17:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 025': {'roomNumber': 'ACE 025', 'slots': [{'StartTime': '08:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 102': {'roomNumber': 'ACE 102', 'slots': [{'StartTime': '14:30', 'EndTime': '16:00', 'Status': ''}, {'StartTime': '19:00', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 122': {'roomNumber': 'ACE 122', 'slots': [{'StartTime': '08:30', 'EndTime': '16:00', 'Status': ''}, {'StartTime': '17:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 132': {'roomNumber': 'ACE 132', 'slots': [{'StartTime': '08:30', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '17:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 147': {'roomNumber': 'ACE 147', 'slots': [{'StartTime': '08:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 201': {'roomNumber': 'ACE 201', 'slots': [{'StartTime': '08:30', 'EndTime': '08:45', 'Status': ''}, {'StartTime': '10:15', 'EndTime': '10:30', 'Status': ''}, {'StartTime': '12:00', 'EndTime': '14:30', 'Status': ''}, {'StartTime': '17:30', 'EndTime': '22:00', 'Status': ''}]}, 'ACE 203': {'roomNumber': 'ACE 203', 'slots': [{'StartTime': '08:30', 'EndTime': '08:45', 'Status': ''}, {'StartTime': '10:15', 'EndTime': '10:30', 'Status': ''}, {'StartTime': '12:00', 'EndTime': '13:00', 'Status': ''}, {'StartTime': '14:30', 'EndTime': '16:30', 'Status': ''}, {'StartTime': '20:30', 'EndTime': '22:00', 'Status':  ...
